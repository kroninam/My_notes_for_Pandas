# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Знакомство с иерархической индексацией

# %% [markdown]
# ## Мульти индексы

# %%
# задаем значнения и индексы серии в явном виде:

s = pd.Series([i for i in range(10, 100,10)], index = [0,1,2,3,4,5,6,7,8])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# 8    90
# dtype: int64

# %%
# для того, чтобы был мультииндекс, в индекс надо передать два массива - индекс первого уровня, индекс второго уровня:

index = [['a', 'a', 'a', 'b', 'b', 'b', 'c', 'c', 'c' ], 
         [ 0,   1,   2,   3,   4,   5,   6,   7,   8]]


s1 = pd.Series([i for i in range(10, 100,10)], index = index)

# %%
s1
# Out:
# a  0    10
#    1    20
#    2    30
# b  3    40
#    4    50
#    5    60
# c  6    70
#    7    80
#    8    90
# dtype: int64

# %%
# вытаскиваем данные из мульти индекса:

s1['a']
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s1['b': 'c']
# Out:
# b  3    40
#    4    50
#    5    60
# c  6    70
#    7    80
#    8    90
# dtype: int64

# %%
s1.loc[['a', 'c']]
# Out:
# a  0    10
#    1    20
#    2    30
# c  6    70
#    7    80
#    8    90
# dtype: int64

# %%
# если мы хотим сразу вытаскивать данные по индексу не с нулевого уровня, а со второго:

s1.loc[:,1] 

# двоеточие говорит о том, что мы игнорируем нулевой индекс, ну или проходимся по нему всему и ищем уже в первом уровне
# Out:
# a    20
# dtype: int64

# %% [markdown]
# ## Раскладываем серию с мультииндексом на датафрейм

# %%
s3 = pd.Series([50000, 45000, 40000, 55000, 47000, 45000, 52000, 43000, 41000], 
               index=[['Тестирование', 'Тестирование', 'Тестирование', 'Разработка', 'Разработка', 'Разработка', 'Аналитика', 'Аналитика', 'Аналитика'], 
                      ['Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист']])

# %%
s3
# Out:
# Тестирование  Начальник     50000
#               Эксперт       45000
#               Специалист    40000
# Разработка    Начальник     55000
#               Эксперт       47000
#               Специалист    45000
# Аналитика     Начальник     52000
#               Эксперт       43000
#               Специалист    41000
# dtype: int64

# %%
s3.unstack()
# Out:
#               Начальник  Специалист  Эксперт
# Аналитика         52000       41000    43000
# Разработка        55000       45000    47000
# Тестирование      50000       40000    45000

# %%
# обратное преобразование датафрейма в серию с мультииндексом:

df = s3.unstack()
df.stack()
# Out:
# Аналитика     Начальник     52000
#               Специалист    41000
#               Эксперт       43000
# Разработка    Начальник     55000
#               Специалист    45000
#               Эксперт       47000
# Тестирование  Начальник     50000
#               Специалист    40000
#               Эксперт       45000
# dtype: int64

# %%
# как в данном случае работает !???
df.unstack()
# Out:
# Начальник   Аналитика       52000
#             Разработка      55000
#             Тестирование    50000
# Специалист  Аналитика       41000
#             Разработка      45000
#             Тестирование    40000
# Эксперт     Аналитика       43000
#             Разработка      47000
#             Тестирование    45000
# dtype: int64

# %% [markdown]
# ## доступ к значениям

# %%
data = np.array([[50000, 16],
                 [45000, 15],
                 [40000, 14],
                 [55000, 15],
                 [47000, 13],
                 [45000, 12],
                 [52000, 17],
                 [43000, 15],
                 [41000, 13]])

index=[['Тестирование', 'Тестирование', 'Тестирование', 'Разработка', 'Разработка', 'Разработка', 'Аналитика', 'Аналитика', 'Аналитика'], 
       ['Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Советник']]

columns = ['Зарплата', 'Уровень']

df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#                          Зарплата  Уровень
# Тестирование Начальник      50000       16
#              Эксперт        45000       15
#              Специалист     40000       14
# Разработка   Начальник      55000       15
#              Эксперт        47000       13
#              Специалист     45000       12
# Аналитика    Начальник      52000       17
#              Эксперт        43000       15
#              Советник       41000       13

# %%
df.loc[('Тестирование', 'Начальник')]
# Out:
# Зарплата    50000
# Уровень        16
# Name: (Тестирование, Начальник), dtype: int32

# %%
df.loc[('Тестирование', 'Начальник'), 'Зарплата']
# Out:
# 50000

# %%
Далее следует Контрольная работа по Мульти индексам.
см. файл : 'stepik_multiindex_lesson_1_v2 / ДЗ - Знакомство с иерархической индексацией (2).ipynb'

# %% [markdown]
# # Действия с мультииндексами в датафреймах

# %%
data = np.array([[50000, 16],
                 [45000, 15],
                 [40000, 14],
                 [55000, 15],
                 [47000, 13],
                 [45000, 12],
                 [52000, 17],
                 [43000, 15],
                 [41000, 13]],
               
               )

index=[['Тестирование', 'Тестирование', 'Тестирование', 'Разработка', 'Разработка', 'Разработка', 'Аналитика', 'Аналитика', 'Аналитика'], 
       ['Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Советник']]

columns = [['Москва', 'Москва'], ['Зарплата', 'Уровень']]

df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#                           Москва
#                         Зарплата Уровень
# Тестирование Начальник     50000      16
#              Эксперт       45000      15
#              Специалист    40000      14
# Разработка   Начальник     55000      15
#              Эксперт       47000      13
#              Специалист    45000      12
# Аналитика    Начальник     52000      17
#              Эксперт       43000      15
#              Советник      41000      13

# %%
data = np.array([[50000, 16, 50000, 16],
                 [45000, 15, 45000, 15,],
                 [40000, 14, 40000, 14],
                 [55000, 15, 55000, 15],
                 [47000, 13, 47000, 13],
                 [45000, 12, 45000, 12],
                 [52000, 17, 52000, 17],
                 [43000, 15, 43000, 15],
                 [41000, 13, 41000, 13]])

# %%
index=[['Тестирование', 'Тестирование', 'Тестирование', 'Разработка', 'Разработка', 'Разработка', 'Аналитика', 'Аналитика', 'Аналитика'], 
       ['Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Советник']]

columns = [['Москва', 'Москва', 'Казань', 'Казань'], ['Зарплата', 'Уровень', 'Зарплата', 'Уровень']]

df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#                           Москва           Казань
#                         Зарплата Уровень Зарплата Уровень
# Тестирование Начальник     50000      16    50000      16
#              Эксперт       45000      15    45000      15
#              Специалист    40000      14    40000      14
# Разработка   Начальник     55000      15    55000      15
#              Эксперт       47000      13    47000      13
#              Специалист    45000      12    45000      12
# Аналитика    Начальник     52000      17    52000      17
#              Эксперт       43000      15    43000      15
#              Советник      41000      13    41000      13

# %%
df['Москва']
# Out:
#                          Зарплата  Уровень
# Тестирование Начальник      50000       16
#              Эксперт        45000       15
#              Специалист     40000       14
# Разработка   Начальник      55000       15
#              Эксперт        47000       13
#              Специалист     45000       12
# Аналитика    Начальник      52000       17
#              Эксперт        43000       15
#              Советник       41000       13

# %%
# можно переименовать уровни индексов и колонок и обращаться к ним не по номерам - нулевой, первый и т.д, а по именам:

# %%
df.index
# Out:
# MultiIndex([('Тестирование',  'Начальник'),
#             ('Тестирование',    'Эксперт'),
#             ('Тестирование', 'Специалист'),
#             (  'Разработка',  'Начальник'),
#             (  'Разработка',    'Эксперт'),
#             (  'Разработка', 'Специалист'),
#             (   'Аналитика',  'Начальник'),
#             (   'Аналитика',    'Эксперт'),
#             (   'Аналитика',   'Советник')],
#            )

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Имя для нулевого уровня', 'Имя для первого уровня']

# %%
df.index.names
# Out:
# FrozenList(['Имя для нулевого уровня', 'Имя для первого уровня'])

# %%
df
# Out:
#                                                  Москва           Казань  \
#                                                Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
#
#                                                Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %%
df.columns
# Out:
# MultiIndex([('Москва', 'Зарплата'),
#             ('Москва',  'Уровень'),
#             ('Казань', 'Зарплата'),
#             ('Казань',  'Уровень')],
#            )

# %%
df.columns.names
# Out:
# FrozenList([None, None])

# %%
df.columns.names = ['Города', 'Показатель']

# %%
df
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %%
# swaplevel - поменять уровни местами

# %%
df.swaplevel(1,0)
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для первого уровня Имя для нулевого уровня
# Начальник              Тестирование               50000      16    50000
# Эксперт                Тестирование               45000      15    45000
# Специалист             Тестирование               40000      14    40000
# Начальник              Разработка                 55000      15    55000
# Эксперт                Разработка                 47000      13    47000
# Специалист             Разработка                 45000      12    45000
# Начальник              Аналитика                  52000      17    52000
# Эксперт                Аналитика                  43000      15    43000
# Советник               Аналитика                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для первого уровня Имя для нулевого уровня
# Начальник              Тестирование                 16
# Эксперт                Тестирование                 15
# Специалист             Тестирование                 14
# Начальник              Разработка                   15
# Эксперт                Разработка                   13
# Специалист             Разработка                   12
# Начальник              Аналитика                    17
# Эксперт                Аналитика                    15
# Советник               Аналитика                    13

# %%
# можно делать swaplevel не по индексам, а по названиям:

df.swaplevel('Имя для первого уровня', 'Имя для нулевого уровня')
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для первого уровня Имя для нулевого уровня
# Начальник              Тестирование               50000      16    50000
# Эксперт                Тестирование               45000      15    45000
# Специалист             Тестирование               40000      14    40000
# Начальник              Разработка                 55000      15    55000
# Эксперт                Разработка                 47000      13    47000
# Специалист             Разработка                 45000      12    45000
# Начальник              Аналитика                  52000      17    52000
# Эксперт                Аналитика                  43000      15    43000
# Советник               Аналитика                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для первого уровня Имя для нулевого уровня
# Начальник              Тестирование                 16
# Эксперт                Тестирование                 15
# Специалист             Тестирование                 14
# Начальник              Разработка                   15
# Эксперт                Разработка                   13
# Специалист             Разработка                   12
# Начальник              Аналитика                    17
# Эксперт                Аналитика                    15
# Советник               Аналитика                    13

# %%
# сортировка мульти индекса

# %%
df.sort_index(level = 0, ascending = False)
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
#                         Начальник                 50000      16    50000
# Разработка              Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
#                         Начальник                 55000      15    55000
# Аналитика               Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#                         Начальник                 52000      17    52000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Эксперт                     15
#                         Специалист                  14
#                         Начальник                   16
# Разработка              Эксперт                     13
#                         Специалист                  12
#                         Начальник                   15
# Аналитика               Эксперт                     15
#                         Советник                    13
#                         Начальник                   17

# %%
df.sort_index(level = 'Имя для первого уровня', ascending = False)
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Эксперт                   45000      15    45000
# Разработка              Эксперт                   47000      13    47000
# Аналитика               Эксперт                   43000      15    43000
# Тестирование            Специалист                40000      14    40000
# Разработка              Специалист                45000      12    45000
# Аналитика               Советник                  41000      13    41000
# Тестирование            Начальник                 50000      16    50000
# Разработка              Начальник                 55000      15    55000
# Аналитика               Начальник                 52000      17    52000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Эксперт                     15
# Разработка              Эксперт                     13
# Аналитика               Эксперт                     15
# Тестирование            Специалист                  14
# Разработка              Специалист                  12
# Аналитика               Советник                    13
# Тестирование            Начальник                   16
# Разработка              Начальник                   15
# Аналитика               Начальник                   17

# %%
df.sort_index(level = 0, axis = 1)
# Out:
# Города                                           Казань           Москва  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %%
# переустановить индексы

# %%
df.reset_index()
# Out:
# Города     Имя для нулевого уровня Имя для первого уровня   Москва          \
# Показатель                                                Зарплата Уровень
# 0                     Тестирование              Начальник    50000      16
# 1                     Тестирование                Эксперт    45000      15
# 2                     Тестирование             Специалист    40000      14
# 3                       Разработка              Начальник    55000      15
# 4                       Разработка                Эксперт    47000      13
# 5                       Разработка             Специалист    45000      12
# 6                        Аналитика              Начальник    52000      17
# 7                        Аналитика                Эксперт    43000      15
# 8                        Аналитика               Советник    41000      13
#
# Города       Казань
# Показатель Зарплата Уровень
# 0             50000      16
# 1             45000      15
# 2             40000      14
# 3             55000      15
# 4             47000      13
# 5             45000      12
# 6             52000      17
# 7             43000      15
# 8             41000      13

# %%
# собрать обратно мульти индекс set_index

# %%
df2 = df.reset_index()

# %%
df2.set_index(['Имя для нулевого уровня', 'Имя для первого уровня'])
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %% [markdown]
# # Суммирование значений с учетом мульти индексов

# %%
df
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %%
df.sum()
# Out:
# Города  Показатель
# Москва  Зарплата      418000
#         Уровень          130
# Казань  Зарплата      418000
#         Уровень          130
# dtype: int64

# %%
df.sum(level = 0)
# Out:
# C:\Users\roman\AppData\Local\Temp\ipykernel_81140\1193966005.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   df.sum(level = 0)
# Города                    Москва           Казань
# Показатель              Зарплата Уровень Зарплата Уровень
# Имя для нулевого уровня
# Тестирование              135000      45   135000      45
# Разработка                147000      40   147000      40
# Аналитика                 136000      45   136000      45

# %%
df.sum(level = 1)
# Out:
# C:\Users\roman\AppData\Local\Temp\ipykernel_81140\1551480555.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   df.sum(level = 1)
# Города                   Москва           Казань
# Показатель             Зарплата Уровень Зарплата Уровень
# Имя для первого уровня
# Начальник                157000      48   157000      48
# Эксперт                  135000      43   135000      43
# Специалист                85000      26    85000      26
# Советник                  41000      13    41000      13

# %%
# Далее идет домашнее задание в отдельном Jupyter Notebooke:

#     Папка называется: Homework_multiindex_2
#     Файл: ДЗ - Действия с мультииндексами в датафреймах.ipynb
