# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Знакомство с иерархической индексацией

# %% [markdown]
# ## Мульти индексы

# %%
# задаем значнения и индексы серии в явном виде:

s = pd.Series([i for i in range(10, 100,10)], index = [0,1,2,3,4,5,6,7,8])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# 8    90
# dtype: int64

# %%
# для того, чтобы был мультииндекс, в индекс надо передать два массива - индекс первого уровня, индекс второго уровня:

index = [['a', 'a', 'a', 'b', 'b', 'b', 'c', 'c', 'c' ], 
         [ 0,   1,   2,   3,   4,   5,   6,   7,   8]]


s1 = pd.Series([i for i in range(10, 100,10)], index = index)

# %%
s1
# Out:
# a  0    10
#    1    20
#    2    30
# b  3    40
#    4    50
#    5    60
# c  6    70
#    7    80
#    8    90
# dtype: int64

# %%
# вытаскиваем данные из мульти индекса:

# все по индексу нулевого уровня:

s1['a']
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s1['b': 'c']
# Out:
# b  3    40
#    4    50
#    5    60
# c  6    70
#    7    80
#    8    90
# dtype: int64

# %%
s1.loc[['a', 'c']]
# Out:
# a  0    10
#    1    20
#    2    30
# c  6    70
#    7    80
#    8    90
# dtype: int64

# %%
# если мы хотим сразу вытаскивать данные по индексу не с нулевого уровня, а с первого - обращаемся к нему:

s1.loc[:,1] 

# двоеточие говорит о том, что мы игнорируем нулевой индекс, ну или проходимся по нему всему и ищем уже в первом уровне
# Out:
# a    20
# dtype: int64

# %% [markdown]
# ## Раскладываем серию с мультииндексом на датафрейм

# %%
s3 = pd.Series([50000, 45000, 40000, 55000, 47000, 45000, 52000, 43000, 41000], 
               index=[['Тестирование', 'Тестирование', 'Тестирование', 'Разработка', 'Разработка', 'Разработка', 'Аналитика', 'Аналитика', 'Аналитика'], 
                      ['Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист']])

# %%
s3
# Out:
# Тестирование  Начальник     50000
#               Эксперт       45000
#               Специалист    40000
# Разработка    Начальник     55000
#               Эксперт       47000
#               Специалист    45000
# Аналитика     Начальник     52000
#               Эксперт       43000
#               Специалист    41000
# dtype: int64

# %%
s3.unstack()
# Out:
#               Начальник  Специалист  Эксперт
# Аналитика         52000       41000    43000
# Разработка        55000       45000    47000
# Тестирование      50000       40000    45000

# %%
# обратное преобразование датафрейма в серию с мультииндексом:

df = s3.unstack()
df.stack()

# %%
# как в данном случае работает !???
df.unstack()
# Out:
# Начальник   Аналитика       52000
#             Разработка      55000
#             Тестирование    50000
# Специалист  Аналитика       41000
#             Разработка      45000
#             Тестирование    40000
# Эксперт     Аналитика       43000
#             Разработка      47000
#             Тестирование    45000
# dtype: int64

# %% [markdown]
# ## доступ к значениям

# %%
data = np.array([[50000, 16],
                 [45000, 15],
                 [40000, 14],
                 [55000, 15],
                 [47000, 13],
                 [45000, 12],
                 [52000, 17],
                 [43000, 15],
                 [41000, 13]])

index=[['Тестирование', 'Тестирование', 'Тестирование', 'Разработка', 'Разработка', 'Разработка', 'Аналитика', 'Аналитика', 'Аналитика'], 
       ['Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Советник']]

columns = ['Зарплата', 'Уровень']

df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#                          Зарплата  Уровень
# Тестирование Начальник      50000       16
#              Эксперт        45000       15
#              Специалист     40000       14
# Разработка   Начальник      55000       15
#              Эксперт        47000       13
#              Специалист     45000       12
# Аналитика    Начальник      52000       17
#              Эксперт        43000       15
#              Советник       41000       13

# %%
df.loc[('Тестирование', 'Начальник')]
# Out:
# Зарплата    50000
# Уровень        16
# Name: (Тестирование, Начальник), dtype: int32

# %%
df.loc[('Тестирование', 'Начальник'), 'Зарплата']
# Out:
# 50000

# %%
Далее следует Контрольная работа по Мульти индексам.

Папка: stepik_multiindex_lesson_1_v2
    
см. файл : 'stepik_multiindex_lesson_1_v2 / ДЗ - Знакомство с иерархической индексацией (2).ipynb'

# %% [markdown]
# # Действия с мультииндексами в датафреймах

# %%
data = np.array([[50000, 16],
                 [45000, 15],
                 [40000, 14],
                 [55000, 15],
                 [47000, 13],
                 [45000, 12],
                 [52000, 17],
                 [43000, 15],
                 [41000, 13]],
               
               )

index=[['Тестирование', 'Тестирование', 'Тестирование', 'Разработка', 'Разработка', 'Разработка', 'Аналитика', 'Аналитика', 'Аналитика'], 
       ['Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Советник']]

columns = [['Москва', 'Москва'], ['Зарплата', 'Уровень']]

df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#                           Москва
#                         Зарплата Уровень
# Тестирование Начальник     50000      16
#              Эксперт       45000      15
#              Специалист    40000      14
# Разработка   Начальник     55000      15
#              Эксперт       47000      13
#              Специалист    45000      12
# Аналитика    Начальник     52000      17
#              Эксперт       43000      15
#              Советник      41000      13

# %%
data = np.array([[50000, 16, 50000, 16],
                 [45000, 15, 45000, 15,],
                 [40000, 14, 40000, 14],
                 [55000, 15, 55000, 15],
                 [47000, 13, 47000, 13],
                 [45000, 12, 45000, 12],
                 [52000, 17, 52000, 17],
                 [43000, 15, 43000, 15],
                 [41000, 13, 41000, 13]])

# %%
index=[['Тестирование', 'Тестирование', 'Тестирование', 'Разработка', 'Разработка', 'Разработка', 'Аналитика', 'Аналитика', 'Аналитика'], 
       ['Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Специалист', 'Начальник', 'Эксперт', 'Советник']]

columns = [['Москва', 'Москва', 'Казань', 'Казань'], ['Зарплата', 'Уровень', 'Зарплата', 'Уровень']]

df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#                           Москва           Казань
#                         Зарплата Уровень Зарплата Уровень
# Тестирование Начальник     50000      16    50000      16
#              Эксперт       45000      15    45000      15
#              Специалист    40000      14    40000      14
# Разработка   Начальник     55000      15    55000      15
#              Эксперт       47000      13    47000      13
#              Специалист    45000      12    45000      12
# Аналитика    Начальник     52000      17    52000      17
#              Эксперт       43000      15    43000      15
#              Советник      41000      13    41000      13

# %%
df['Москва']
# Out:
#                          Зарплата  Уровень
# Тестирование Начальник      50000       16
#              Эксперт        45000       15
#              Специалист     40000       14
# Разработка   Начальник      55000       15
#              Эксперт        47000       13
#              Специалист     45000       12
# Аналитика    Начальник      52000       17
#              Эксперт        43000       15
#              Советник       41000       13

# %%
# можно переименовать уровни индексов и колонок и обращаться к ним не по номерам - нулевой, первый и т.д, а по именам:

# %%
df.index
# Out:
# MultiIndex([('Тестирование',  'Начальник'),
#             ('Тестирование',    'Эксперт'),
#             ('Тестирование', 'Специалист'),
#             (  'Разработка',  'Начальник'),
#             (  'Разработка',    'Эксперт'),
#             (  'Разработка', 'Специалист'),
#             (   'Аналитика',  'Начальник'),
#             (   'Аналитика',    'Эксперт'),
#             (   'Аналитика',   'Советник')],
#            )

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Имя для нулевого уровня', 'Имя для первого уровня']

# %%
df.index.names
# Out:
# FrozenList(['Имя для нулевого уровня', 'Имя для первого уровня'])

# %%
df
# Out:
#                                                  Москва           Казань  \
#                                                Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
#
#                                                Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %%
df.columns
# Out:
# MultiIndex([('Москва', 'Зарплата'),
#             ('Москва',  'Уровень'),
#             ('Казань', 'Зарплата'),
#             ('Казань',  'Уровень')],
#            )

# %%
df.columns.names
# Out:
# FrozenList([None, None])

# %%
df.columns.names = ['Города', 'Показатель']

# %%
df
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %%
# swaplevel - поменять уровни местами

# %%
df.swaplevel(1,0)
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для первого уровня Имя для нулевого уровня
# Начальник              Тестирование               50000      16    50000
# Эксперт                Тестирование               45000      15    45000
# Специалист             Тестирование               40000      14    40000
# Начальник              Разработка                 55000      15    55000
# Эксперт                Разработка                 47000      13    47000
# Специалист             Разработка                 45000      12    45000
# Начальник              Аналитика                  52000      17    52000
# Эксперт                Аналитика                  43000      15    43000
# Советник               Аналитика                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для первого уровня Имя для нулевого уровня
# Начальник              Тестирование                 16
# Эксперт                Тестирование                 15
# Специалист             Тестирование                 14
# Начальник              Разработка                   15
# Эксперт                Разработка                   13
# Специалист             Разработка                   12
# Начальник              Аналитика                    17
# Эксперт                Аналитика                    15
# Советник               Аналитика                    13

# %%
# можно делать swaplevel не по индексам, а по названиям:

df.swaplevel('Имя для первого уровня', 'Имя для нулевого уровня')
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для первого уровня Имя для нулевого уровня
# Начальник              Тестирование               50000      16    50000
# Эксперт                Тестирование               45000      15    45000
# Специалист             Тестирование               40000      14    40000
# Начальник              Разработка                 55000      15    55000
# Эксперт                Разработка                 47000      13    47000
# Специалист             Разработка                 45000      12    45000
# Начальник              Аналитика                  52000      17    52000
# Эксперт                Аналитика                  43000      15    43000
# Советник               Аналитика                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для первого уровня Имя для нулевого уровня
# Начальник              Тестирование                 16
# Эксперт                Тестирование                 15
# Специалист             Тестирование                 14
# Начальник              Разработка                   15
# Эксперт                Разработка                   13
# Специалист             Разработка                   12
# Начальник              Аналитика                    17
# Эксперт                Аналитика                    15
# Советник               Аналитика                    13

# %%
# сортировка мульти индекса

# %%
df.sort_index(level = 0, ascending = False)
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
#                         Начальник                 50000      16    50000
# Разработка              Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
#                         Начальник                 55000      15    55000
# Аналитика               Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#                         Начальник                 52000      17    52000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Эксперт                     15
#                         Специалист                  14
#                         Начальник                   16
# Разработка              Эксперт                     13
#                         Специалист                  12
#                         Начальник                   15
# Аналитика               Эксперт                     15
#                         Советник                    13
#                         Начальник                   17

# %%
df.sort_index(level = 'Имя для первого уровня', ascending = False)
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Эксперт                   45000      15    45000
# Разработка              Эксперт                   47000      13    47000
# Аналитика               Эксперт                   43000      15    43000
# Тестирование            Специалист                40000      14    40000
# Разработка              Специалист                45000      12    45000
# Аналитика               Советник                  41000      13    41000
# Тестирование            Начальник                 50000      16    50000
# Разработка              Начальник                 55000      15    55000
# Аналитика               Начальник                 52000      17    52000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Эксперт                     15
# Разработка              Эксперт                     13
# Аналитика               Эксперт                     15
# Тестирование            Специалист                  14
# Разработка              Специалист                  12
# Аналитика               Советник                    13
# Тестирование            Начальник                   16
# Разработка              Начальник                   15
# Аналитика               Начальник                   17

# %%
df.sort_index(level = 0, axis = 1)
# Out:
# Города                                           Казань           Москва  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %%
# переустановить индексы

# %%
df.reset_index()
# Out:
# Города     Имя для нулевого уровня Имя для первого уровня   Москва          \
# Показатель                                                Зарплата Уровень
# 0                     Тестирование              Начальник    50000      16
# 1                     Тестирование                Эксперт    45000      15
# 2                     Тестирование             Специалист    40000      14
# 3                       Разработка              Начальник    55000      15
# 4                       Разработка                Эксперт    47000      13
# 5                       Разработка             Специалист    45000      12
# 6                        Аналитика              Начальник    52000      17
# 7                        Аналитика                Эксперт    43000      15
# 8                        Аналитика               Советник    41000      13
#
# Города       Казань
# Показатель Зарплата Уровень
# 0             50000      16
# 1             45000      15
# 2             40000      14
# 3             55000      15
# 4             47000      13
# 5             45000      12
# 6             52000      17
# 7             43000      15
# 8             41000      13

# %%
# собрать обратно мульти индекс set_index

# %%
df2 = df.reset_index()

# %%
df2.set_index(['Имя для нулевого уровня', 'Имя для первого уровня'])
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %% [markdown]
# # Суммирование значений с учетом мульти индексов

# %%
df
# Out:
# Города                                           Москва           Казань  \
# Показатель                                     Зарплата Уровень Зарплата
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                 50000      16    50000
#                         Эксперт                   45000      15    45000
#                         Специалист                40000      14    40000
# Разработка              Начальник                 55000      15    55000
#                         Эксперт                   47000      13    47000
#                         Специалист                45000      12    45000
# Аналитика               Начальник                 52000      17    52000
#                         Эксперт                   43000      15    43000
#                         Советник                  41000      13    41000
#
# Города
# Показатель                                     Уровень
# Имя для нулевого уровня Имя для первого уровня
# Тестирование            Начальник                   16
#                         Эксперт                     15
#                         Специалист                  14
# Разработка              Начальник                   15
#                         Эксперт                     13
#                         Специалист                  12
# Аналитика               Начальник                   17
#                         Эксперт                     15
#                         Советник                    13

# %%
df.sum()
# Out:
# Города  Показатель
# Москва  Зарплата      418000
#         Уровень          130
# Казань  Зарплата      418000
#         Уровень          130
# dtype: int64

# %%
df.sum(level = 0)
# Out:
# C:\Users\roman\AppData\Local\Temp\ipykernel_81140\1193966005.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   df.sum(level = 0)
# Города                    Москва           Казань
# Показатель              Зарплата Уровень Зарплата Уровень
# Имя для нулевого уровня
# Тестирование              135000      45   135000      45
# Разработка                147000      40   147000      40
# Аналитика                 136000      45   136000      45

# %%
df.sum(level = 1)
# Out:
# C:\Users\roman\AppData\Local\Temp\ipykernel_81140\1551480555.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   df.sum(level = 1)
# Города                   Москва           Казань
# Показатель             Зарплата Уровень Зарплата Уровень
# Имя для первого уровня
# Начальник                157000      48   157000      48
# Эксперт                  135000      43   135000      43
# Специалист                85000      26    85000      26
# Советник                  41000      13    41000      13

# %%
Далее идет домашнее задание в отдельном Jupyter Notebooke:

    Папка называется: Homework_multiindex_2

    Файл: ДЗ - Действия с мультииндексами в датафреймах.ipynb

# %% [markdown]
# # Учимся соединять датафреймы с помощью merge

# %%
df1 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Зарплата': [55000, 52000, 50000, 45000, 30000]})

df2 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Премия': [15000, 12000, 10000, 9000, 3000]})

# %%
df1
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1    Советник     52000
# 2     Эксперт     50000
# 3  Специалист     45000
# 4      Стажер     30000

# %%
df2
# Out:
#     Должность  Премия
# 0   Начальник   15000
# 1    Советник   12000
# 2     Эксперт   10000
# 3  Специалист    9000
# 4      Стажер    3000

# %%
pd.merge(df1, df2)
# Out:
#     Должность  Зарплата  Премия
# 0   Начальник     55000   15000
# 1    Советник     52000   12000
# 2     Эксперт     50000   10000
# 3  Специалист     45000    9000
# 4      Стажер     30000    3000

# %%
# Если общих колонок нет - будет ошибка, не по чему мержить...

# %%
# Если общих колонок несколько, то можно указать по какой именно производить merge:

pd.merge(df1, df2, on = 'Должность')
# Out:
#     Должность  Зарплата  Премия
# 0   Начальник     55000   15000
# 1    Советник     52000   12000
# 2     Эксперт     50000   10000
# 3  Специалист     45000    9000
# 4      Стажер     30000    3000

# %%
# Если в одном датафрейме данных больше, чем во втором - по умолчаню отобразятся только те, которые есть в обоих:

df1 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Зарплата': [55000, 52000, 50000, 45000, 30000]})

df2 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист'],
                    'Премия': [15000, 12000, 10000, 9000]})

# %%
df1
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1    Советник     52000
# 2     Эксперт     50000
# 3  Специалист     45000
# 4      Стажер     30000

# %%
df2
# Out:
#     Должность  Премия
# 0   Начальник   15000
# 1    Советник   12000
# 2     Эксперт   10000
# 3  Специалист    9000

# %%
pd.merge(df1, df2)
# Out:
#     Должность  Зарплата  Премия
# 0   Начальник     55000   15000
# 1    Советник     52000   12000
# 2     Эксперт     50000   10000
# 3  Специалист     45000    9000

# %%
# можно указать как именно мёржить - по аналогии с left join: 
pd.merge(df1, df2, how = 'left')
# Out:
#     Должность  Зарплата   Премия
# 0   Начальник     55000  15000.0
# 1    Советник     52000  12000.0
# 2     Эксперт     50000  10000.0
# 3  Специалист     45000   9000.0
# 4      Стажер     30000      NaN

# %%
# how может быть right

df1 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Зарплата': [55000, 52000, 50000, 45000, 30000]})

df2 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Тренер'],
                    'Премия': [15000, 12000, 10000, 9000, 3000]})

# %%
df1
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1    Советник     52000
# 2     Эксперт     50000
# 3  Специалист     45000
# 4      Стажер     30000

# %%
df2
# Out:
#     Должность  Премия
# 0   Начальник   15000
# 1    Советник   12000
# 2     Эксперт   10000
# 3  Специалист    9000
# 4      Тренер    3000

# %%
pd.merge(df1, df2, how = 'right')
# Out:
#     Должность  Зарплата  Премия
# 0   Начальник   55000.0   15000
# 1    Советник   52000.0   12000
# 2     Эксперт   50000.0   10000
# 3  Специалист   45000.0    9000
# 4      Тренер       NaN    3000

# %%
# объединяем всё
pd.merge(df1, df2, how='outer')
# Out:
#     Должность  Зарплата   Премия
# 0   Начальник   55000.0  15000.0
# 1    Советник   52000.0  12000.0
# 2     Эксперт   50000.0  10000.0
# 3  Специалист   45000.0   9000.0
# 4      Стажер   30000.0      NaN
# 5      Тренер       NaN   3000.0

# %%
Дргуие варианты в документации
https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
# Если названия столбцов с одинаковыми индентификаторами различаются: Должность и Должность2 например:

df1 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Зарплата': [55000, 52000, 50000, 45000, 30000]})

df2 = pd.DataFrame({'Должность2': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Тренер'],
                    'Премия': [15000, 12000, 10000, 9000, 3000]})

# %%
df1
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1    Советник     52000
# 2     Эксперт     50000
# 3  Специалист     45000
# 4      Стажер     30000

# %%
df2
# Out:
#    Должность2  Премия
# 0   Начальник   15000
# 1    Советник   12000
# 2     Эксперт   10000
# 3  Специалист    9000
# 4      Тренер    3000

# %%
pd.merge(df1, df2, right_on = 'Должность2', left_on = 'Должность')
# Out:
#     Должность  Зарплата  Должность2  Премия
# 0   Начальник     55000   Начальник   15000
# 1    Советник     52000    Советник   12000
# 2     Эксперт     50000     Эксперт   10000
# 3  Специалист     45000  Специалист    9000

# %% [markdown]
# ### Дубликаты

# %%
df1 = pd.DataFrame({'Должность': ['Начальник', 'Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Зарплата': [55000, 51000, 52000, 50000, 45000, 30000]})

df2 = pd.DataFrame({'Должность': ['Начальник','Начальник', 'Советник', 'Эксперт', 'Специалист', 'Тренер'],
                    'Премия': [15000, 10000, 12000, 10000, 9000, 3000]})

# %%
df1
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1   Начальник     51000
# 2    Советник     52000
# 3     Эксперт     50000
# 4  Специалист     45000
# 5      Стажер     30000

# %%
df2
# Out:
#     Должность  Премия
# 0   Начальник   15000
# 1   Начальник   10000
# 2    Советник   12000
# 3     Эксперт   10000
# 4  Специалист    9000
# 5      Тренер    3000

# %%
pd.merge(df1, df2)
# Out:
#     Должность  Зарплата  Премия
# 0   Начальник     55000   15000
# 1   Начальник     55000   10000
# 2   Начальник     51000   15000
# 3   Начальник     51000   10000
# 4    Советник     52000   12000
# 5     Эксперт     50000   10000
# 6  Специалист     45000    9000

# %%
df3 = pd.merge(df1, df2)

# %%
# показываем df3 где есть дубликаты по колонке должность, сохраняем-выводим все дубликаты
df3[df3.duplicated(subset = 'Должность', keep = False)]
# Out:
#    Должность  Зарплата  Премия
# 0  Начальник     55000   15000
# 1  Начальник     55000   10000
# 2  Начальник     51000   15000
# 3  Начальник     51000   10000

# %%
# Если есть еще одинаковые колонки, но мы объединяем не по ним:

df1 = pd.DataFrame({'Должность': ['Начальник', 'Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Зарплата': [55000, 51000, 52000, 50000, 45000, 30000]})

df2 = pd.DataFrame({'Должность': ['Начальник','Начальник', 'Советник', 'Эксперт', 'Специалист', 'Тренер'],
                    'Зарплата': [15000, 11000, 12000, 10000, 15000, 10000],
                    'Премия': [15000, 10000, 12000, 10000, 9000, 3000]})

# %%
df1
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1   Начальник     51000
# 2    Советник     52000
# 3     Эксперт     50000
# 4  Специалист     45000
# 5      Стажер     30000

# %%
df2
# Out:
#     Должность  Зарплата  Премия
# 0   Начальник     15000   15000
# 1   Начальник     11000   10000
# 2    Советник     12000   12000
# 3     Эксперт     10000   10000
# 4  Специалист     15000    9000
# 5      Тренер     10000    3000

# %%
pd.merge(df1, df2, on = 'Должность')
# Out:
#     Должность  Зарплата_x  Зарплата_y  Премия
# 0   Начальник       55000       15000   15000
# 1   Начальник       55000       11000   10000
# 2   Начальник       51000       15000   15000
# 3   Начальник       51000       11000   10000
# 4    Советник       52000       12000   12000
# 5     Эксперт       50000       10000   10000
# 6  Специалист       45000       15000    9000

# %%
# отображать вместо x и y можно любые suffixes:

pd.merge(df1, df2, on = 'Должность', suffixes = ('_один', '_джва'))
# Out:
#     Должность  Зарплата_один  Зарплата_джва  Премия
# 0   Начальник          55000          15000   15000
# 1   Начальник          55000          11000   10000
# 2   Начальник          51000          15000   15000
# 3   Начальник          51000          11000   10000
# 4    Советник          52000          12000   12000
# 5     Эксперт          50000          10000   10000
# 6  Специалист          45000          15000    9000

# %%
df3 = pd.merge(df1, df2, on = 'Должность', suffixes = ('_один', '_джва'))

# %%
df3['Зарплата_джва']
# Out:
# 0    15000
# 1    11000
# 2    15000
# 3    11000
# 4    12000
# 5    10000
# 6    15000
# Name: Зарплата_джва, dtype: int64

# %% [markdown]
# # Работа функции merge
# когда в одном из сливаемых датафреймов сливаемая колонка == индексу

# %%
df2 = df2.set_index('Должность')

# %%
df2
# Out:
#             Зарплата  Премия
# Должность
# Начальник      15000   15000
# Начальник      11000   10000
# Советник       12000   12000
# Эксперт        10000   10000
# Специалист     15000    9000
# Тренер         10000    3000

# %%
df1
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1   Начальник     51000
# 2    Советник     52000
# 3     Эксперт     50000
# 4  Специалист     45000
# 5      Стажер     30000

# %%
pd.merge(df1, df2, on = 'Должность')
# Out:
#     Должность  Зарплата_x  Зарплата_y  Премия
# 0   Начальник       55000       15000   15000
# 1   Начальник       55000       11000   10000
# 2   Начальник       51000       15000   15000
# 3   Начальник       51000       11000   10000
# 4    Советник       52000       12000   12000
# 5     Эксперт       50000       10000   10000
# 6  Специалист       45000       15000    9000

# %%
# если индекс еще и по-другому называется, а сливать нужно именно по индексу

# %%
df2.index.name = 'position'

# %%
df2
# Out:
#             Зарплата  Премия
# position
# Начальник      15000   15000
# Начальник      11000   10000
# Советник       12000   12000
# Эксперт        10000   10000
# Специалист     15000    9000
# Тренер         10000    3000

# %%
df1
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1   Начальник     51000
# 2    Советник     52000
# 3     Эксперт     50000
# 4  Специалист     45000
# 5      Стажер     30000

# %%
pd.merge(df1, df2, left_on = 'Должность', right_on = df2.index.name) # также может быть right_index = True
# Out:
#     Должность  Зарплата_x  Зарплата_y  Премия
# 0   Начальник       55000       15000   15000
# 1   Начальник       55000       11000   10000
# 2   Начальник       51000       15000   15000
# 3   Начальник       51000       11000   10000
# 4    Советник       52000       12000   12000
# 5     Эксперт       50000       10000   10000
# 6  Специалист       45000       15000    9000

# %%
# если названия индексов затерты:
df1 = df1.set_index('Должность')
df2 = df2.set_index('Должность')
df1.index.name = None
df2.index.name = None

# %%
df1
# Out:
#             Зарплата
# Начальник      55000
# Начальник      51000
# Советник       52000
# Эксперт        50000
# Специалист     45000
# Стажер         30000

# %%
df2
# Out:
#             Зарплата  Премия
# Начальник      15000   15000
# Начальник      11000   10000
# Советник       12000   12000
# Эксперт        10000   10000
# Специалист     15000    9000
# Тренер         10000    3000

# %%
pd.merge(df1, df2, left_index = True, right_index = True)
# Out:
#             Зарплата_x  Зарплата_y  Премия
# Начальник        55000       15000   15000
# Начальник        55000       11000   10000
# Начальник        51000       15000   15000
# Начальник        51000       11000   10000
# Советник         52000       12000   12000
# Специалист       45000       15000    9000
# Эксперт          50000       10000   10000

# %%
# Объединение по нескольким индексам

# %%
df1 = pd.DataFrame({'Должность': ['Начальник', 'Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер', 'Учитель'],
                    'Филиал': ['1', '2', '1', '1', '1', '1', '1'],
                    'Зарплата': [55000, 51000, 52000, 50000, 45000, 30000, 30000]})

df2 = pd.DataFrame({'Должность': ['Начальник','Советник', 'Эксперт', 'Специалист', 'Стажер','Тренер', 'Начальник'],
                    'Филиал': ['1', '1', '1', '1', '1', '1', '2'],
                    'Зарплата': [115000, 111000, 112000, 110000, 115000, 110000, 145000],
                    'Премия': [15000, 10000, 12000, 10000, 9000, 3000, 20000]})

# %%
df1
# Out:
#     Должность Филиал  Зарплата
# 0   Начальник      1     55000
# 1   Начальник      2     51000
# 2    Советник      1     52000
# 3     Эксперт      1     50000
# 4  Специалист      1     45000
# 5      Стажер      1     30000
# 6     Учитель      1     30000

# %%
df2
# Out:
#     Должность Филиал  Зарплата  Премия
# 0   Начальник      1    115000   15000
# 1    Советник      1    111000   10000
# 2     Эксперт      1    112000   12000
# 3  Специалист      1    110000   10000
# 4      Стажер      1    115000    9000
# 5      Тренер      1    110000    3000
# 6   Начальник      2    145000   20000

# %%
pd.merge(df1, df2, on = ['Должность', 'Филиал'])
# Out:
#     Должность Филиал  Зарплата_x  Зарплата_y  Премия
# 0   Начальник      1       55000      115000   15000
# 1   Начальник      2       51000      145000   20000
# 2    Советник      1       52000      111000   10000
# 3     Эксперт      1       50000      112000   12000
# 4  Специалист      1       45000      110000   10000
# 5      Стажер      1       30000      115000    9000

# %%
# а если в одном из датафреймов название колонки сбито в индекс:

df2.set_index('Должность')
# Out:
#            Филиал  Зарплата  Премия
# Должность
# Начальник       1    115000   15000
# Советник        1    111000   10000
# Эксперт         1    112000   12000
# Специалист      1    110000   10000
# Стажер          1    115000    9000
# Тренер          1    110000    3000
# Начальник       2    145000   20000

# %%
df2 = df2.set_index('Должность')
df2.index.name = None

# %%
df2
# Out:
#            Филиал  Зарплата  Премия
# Начальник       1    115000   15000
# Советник        1    111000   10000
# Эксперт         1    112000   12000
# Специалист      1    110000   10000
# Стажер          1    115000    9000
# Тренер          1    110000    3000
# Начальник       2    145000   20000

# %%
df1
# Out:
#     Должность Филиал  Зарплата
# 0   Начальник      1     55000
# 1   Начальник      2     51000
# 2    Советник      1     52000
# 3     Эксперт      1     50000
# 4  Специалист      1     45000
# 5      Стажер      1     30000
# 6     Учитель      1     30000

# %%
pd.merge(df1, df2, left_on = ['Должность', 'Филиал'], right_on = [df2.index, 'Филиал'])
# Out:
#     Должность Филиал  Зарплата_x  Зарплата_y  Премия
# 0   Начальник      1       55000      115000   15000
# 1   Начальник      2       51000      145000   20000
# 2    Советник      1       52000      111000   10000
# 3     Эксперт      1       50000      112000   12000
# 4  Специалист      1       45000      110000   10000
# 5      Стажер      1       30000      115000    9000

# %%
# если в одном из датафреймов в индекс сбито два столбца и сделан мульти индекс:

df2.set_index(['Должность','Филиал'])
# Out:
#                    Зарплата  Премия
# Должность  Филиал
# Начальник  1         115000   15000
# Советник   1         111000   10000
# Эксперт    1         112000   12000
# Специалист 1         110000   10000
# Стажер     1         115000    9000
# Тренер     1         110000    3000
# Начальник  2         145000   20000

# %%
df2 = df2.set_index(['Должность','Филиал'])

# %%
df2.index.names = [None, None]

# %%
df2
# Out:
#               Зарплата  Премия
# Начальник  1    115000   15000
# Советник   1    111000   10000
# Эксперт    1    112000   12000
# Специалист 1    110000   10000
# Стажер     1    115000    9000
# Тренер     1    110000    3000
# Начальник  2    145000   20000

# %%
pd.merge(df1, df2, left_on = ['Должность', 'Филиал'], right_index = True)
# Out:
#     Должность Филиал  Зарплата_x  Зарплата_y  Премия
# 0   Начальник      1       55000      115000   15000
# 1   Начальник      2       51000      145000   20000
# 2    Советник      1       52000      111000   10000
# 3     Эксперт      1       50000      112000   12000
# 4  Специалист      1       45000      110000   10000
# 5      Стажер      1       30000      115000    9000

# %% [markdown]
# # ДОМАШНЕЕ ЗАДАНИЕ

# %%
Файлы скачены под соответствующими именами:

main.csv - основная информация о предприятиях общественного питания


net_property.csv - является ли предприятие сетевым


seats_property.csv - количество посадочных мест


type_property.csv - информация о специализации: столовая, закусочная, кафе, иное

# %% [markdown]
# # Задание№1

# %%
# Определите процент объектов у которых запись о специализации отсутствует или не 
# является актуальной. Получившийся процент округлите до целых.

# В ответе не указывайте знак процента.

# %%
df = pd.read_csv('type_property.csv')

# %%
df1 = pd.read_csv('main.csv')

# %%
# тут определяем что nan нет в df
df[df['is_actual'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, TypeObject, is_actual]
# Index: []

# %%
df1
# Out:
#           ID               Name  \
# 0      20988                ГУЗ
# 1      24828        Кафе Халяль
# 2     358126           Scarface
# 3     373052         Кулинариум
# 4     303239   One price coffee
# ...      ...                ...
# 9995  192373         Рамен Клаб
# 9996  204304         Папа Джонс
# 9997  301366           Up Sushi
# 9998  339278             Шаурма
# 9999   23511  Столовая при ММВЗ
#
#                                                 Address
# 0                  город Москва, улица Казакова, дом 15
# 1     город Москва, 8-я улица Текстильщиков, дом 5, ...
# 2     Российская Федерация, город Москва, внутригоро...
# 3     Российская Федерация, город Москва, внутригоро...
# 4     Российская Федерация, город Москва, внутригоро...
# ...                                                 ...
# 9995              город Москва, Мясницкая улица, дом 16
# 9996      город Москва, проспект Маршала Жукова, дом 59
# 9997  город Москва, город Московский, улица Москвити...
# 9998  город Москва, улица Орджоникидзе, дом 12, стро...
# 9999              город Москва, Рябиновая улица, дом 53
#
# [10000 rows x 3 columns]

# %%
df
# Out:
#            ID  TypeObject  is_actual
# 0      302619  закусочная       True
# 1       28573    столовая       True
# 2      373269        кафе      False
# 3       29517    столовая       True
# 4      368413        кафе      False
# ...       ...         ...        ...
# 12995  302916        кафе      False
# 12996   23238        кафе       True
# 12997  286294        кафе      False
# 12998  318855    столовая      False
# 12999  348824        кафе       True
#
# [13000 rows x 3 columns]

# %%
# Это самая сложная часть задания - т.к. надо поянть, что main.csv содержит информацю об объектах,
# а type_property.csv содержит информаию об актуальности и количестово записей в них не равно

# количество записей в type_property.csv больше, это значит что все лишние записи относительно main.csv - это неактуальные

pd.merge(df, df1, how = 'right')
# Out:
#           ID                         TypeObject is_actual               Name  \
# 0      20988                           столовая      True                ГУЗ
# 1      24828                                NaN       NaN        Кафе Халяль
# 2     358126                               кафе      True           Scarface
# 3     373052                          кафетерий     False         Кулинариум
# 4     303239                                NaN       NaN   One price coffee
# ...      ...                                ...       ...                ...
# 9995  192373                                NaN       NaN         Рамен Клаб
# 9996  204304                               кафе     False         Папа Джонс
# 9997  301366                               кафе     False           Up Sushi
# 9998  339278  предприятие быстрого обслуживания      True             Шаурма
# 9999   23511                           столовая      True  Столовая при ММВЗ
#
#                                                 Address
# 0                  город Москва, улица Казакова, дом 15
# 1     город Москва, 8-я улица Текстильщиков, дом 5, ...
# 2     Российская Федерация, город Москва, внутригоро...
# 3     Российская Федерация, город Москва, внутригоро...
# 4     Российская Федерация, город Москва, внутригоро...
# ...                                                 ...
# 9995              город Москва, Мясницкая улица, дом 16
# 9996      город Москва, проспект Маршала Жукова, дом 59
# 9997  город Москва, город Московский, улица Москвити...
# 9998  город Москва, улица Орджоникидзе, дом 12, стро...
# 9999              город Москва, Рябиновая улица, дом 53
#
# [10000 rows x 5 columns]

# %%
df3 = pd.merge(df, df1, how = 'right')

# %%
df3['ID'][(df3['is_actual'] == False) | (df3['is_actual'].isna())].count()
# Out:
# 6710

# %%
df3['ID'].count()
# Out:
# 10000

# %%
100*(df3['ID'][(df3['is_actual']== False) | (df3['is_actual'].isna())].count() / df3['ID'].count())
# Out:
# 67.10000000000001

# %% [markdown]
# # Задание 2

# %%
# Подтяните к исходному списку (main.csv) последние данные о числе посадочных мест для каждого объекта. 
# Сколько всего посадочных мест получилось?

# %%
df1 = pd.read_csv('main.csv')

# %%
df2 = pd.read_csv('seats_property.csv')

# %%
df1
# Out:
#           ID               Name  \
# 0      20988                ГУЗ
# 1      24828        Кафе Халяль
# 2     358126           Scarface
# 3     373052         Кулинариум
# 4     303239   One price coffee
# ...      ...                ...
# 9995  192373         Рамен Клаб
# 9996  204304         Папа Джонс
# 9997  301366           Up Sushi
# 9998  339278             Шаурма
# 9999   23511  Столовая при ММВЗ
#
#                                                 Address
# 0                  город Москва, улица Казакова, дом 15
# 1     город Москва, 8-я улица Текстильщиков, дом 5, ...
# 2     Российская Федерация, город Москва, внутригоро...
# 3     Российская Федерация, город Москва, внутригоро...
# 4     Российская Федерация, город Москва, внутригоро...
# ...                                                 ...
# 9995              город Москва, Мясницкая улица, дом 16
# 9996      город Москва, проспект Маршала Жукова, дом 59
# 9997  город Москва, город Московский, улица Москвити...
# 9998  город Москва, улица Орджоникидзе, дом 12, стро...
# 9999              город Москва, Рябиновая улица, дом 53
#
# [10000 rows x 3 columns]

# %%
df2
# Out:
#            ID  SeatsCount  ver_ID
# 0      345181           0       1
# 1      326754          35       2
# 2      151037           0       1
# 3      277311          11       2
# 4      252377           2       1
# ...       ...         ...     ...
# 12995   58472          90       1
# 12996  372280          35       2
# 12997   26058         310       1
# 12998  190988          40       1
# 12999  356817           4       1
#
# [13000 rows x 3 columns]

# %%
# Сортируем данные сначала по ID потом по ver_ID (получается если есть дубликаты, то сначала будет 2, потом 1)


df2.sort_values(by = ['ID', 'ver_ID'], ascending = False)
# Out:
#            ID  SeatsCount  ver_ID
# 6693   375956           0       1
# 8853   375956           0       1
# 2158   375942           0       1
# 6456   375942           0       1
# 8637   375940          10       2
# ...       ...         ...     ...
# 6813    19678          46       1
# 10104   19657          85       2
# 3965    19627          20       2
# 11411   19627          20       2
# 673      5882          75       2
#
# [13000 rows x 3 columns]

# %%
df2.sort_values(by = ['ID', 'ver_ID'], ascending = False).head(10)
# Out:
#            ID  SeatsCount  ver_ID
# 6693   375956           0       1
# 8853   375956           0       1
# 2158   375942           0       1
# 6456   375942           0       1
# 8637   375940          10       2
# 8218   375933           5       2
# 2212   375905          34       1
# 4598   375903          45       2
# 3576   375903          40       1
# 12339  375884          17       2

# %%
# дропаем дубликаты, оставляем только первый - а это с ver_ID == 2.

# таким образом остаются либо чистые ver_ID == 2 либо ver_ID == 1 (у которых и не было обновлений до 2)

df2.sort_values(by = ['ID', 'ver_ID'], ascending = False).drop_duplicates(subset = 'ID', keep = 'first')
# Out:
#            ID  SeatsCount  ver_ID
# 6693   375956           0       1
# 2158   375942           0       1
# 8637   375940          10       2
# 8218   375933           5       2
# 2212   375905          34       1
# ...       ...         ...     ...
# 1449    19681          24       1
# 5032    19678          46       1
# 10104   19657          85       2
# 3965    19627          20       2
# 673      5882          75       2
#
# [8432 rows x 3 columns]

# %%
# получаем новый df3:

df3 = df2.sort_values(by = ['ID', 'ver_ID'], ascending = False).drop_duplicates(subset = 'ID', keep = 'first')

# %%
pd.merge(df1, df3, how = 'left')
# Out:
#           ID               Name  \
# 0      20988                ГУЗ
# 1      24828        Кафе Халяль
# 2     358126           Scarface
# 3     373052         Кулинариум
# 4     303239   One price coffee
# ...      ...                ...
# 9995  192373         Рамен Клаб
# 9996  204304         Папа Джонс
# 9997  301366           Up Sushi
# 9998  339278             Шаурма
# 9999   23511  Столовая при ММВЗ
#
#                                                 Address  SeatsCount  ver_ID
# 0                  город Москва, улица Казакова, дом 15         NaN     NaN
# 1     город Москва, 8-я улица Текстильщиков, дом 5, ...         NaN     NaN
# 2     Российская Федерация, город Москва, внутригоро...         NaN     NaN
# 3     Российская Федерация, город Москва, внутригоро...         4.0     1.0
# 4     Российская Федерация, город Москва, внутригоро...         5.0     2.0
# ...                                                 ...         ...     ...
# 9995              город Москва, Мясницкая улица, дом 16         NaN     NaN
# 9996      город Москва, проспект Маршала Жукова, дом 59         NaN     NaN
# 9997  город Москва, город Московский, улица Москвити...         NaN     NaN
# 9998  город Москва, улица Орджоникидзе, дом 12, стро...         0.0     1.0
# 9999              город Москва, Рябиновая улица, дом 53       134.0     1.0
#
# [10000 rows x 5 columns]

# %%
pd.merge(df1, df3, how = 'left')['SeatsCount'].sum()
# Out:
# 188241.0

# %%
pd.merge(df1, df3, how = 'inner')
# Out:
#           ID                  Name  \
# 0     373052            Кулинариум
# 1     303239      One price coffee
# 2     342854  МЯСОЕД STEAK&BRISKET
# 3     363640        Шаурма-выпечка
# 4     254675              Timeless
# ...      ...                   ...
# 4076  217689              Cinnabon
# 4077  349213        Выпечка шаурма
# 4078  272248                Шаурма
# 4079  339278                Шаурма
# 4080   23511     Столовая при ММВЗ
#
#                                                 Address  SeatsCount  ver_ID
# 0     Российская Федерация, город Москва, внутригоро...           4       1
# 1     Российская Федерация, город Москва, внутригоро...           5       2
# 2           город Москва, проспект Вернадского, дом 86В           5       2
# 3     Российская Федерация, город Москва, внутригоро...           5       2
# 4     Российская Федерация, город Москва, внутригоро...          31       2
# ...                                                 ...         ...     ...
# 4076              город Москва, Ярцевская улица, дом 19          17       2
# 4077   город Москва, проспект Защитников Москвы, дом 10           0       1
# 4078  Российская Федерация, город Москва, внутригоро...           0       1
# 4079  город Москва, улица Орджоникидзе, дом 12, стро...           0       1
# 4080              город Москва, Рябиновая улица, дом 53         134       1
#
# [4081 rows x 5 columns]

# %%
pd.merge(df1, df3, how = 'inner')['SeatsCount'].sum()
# Out:
# 188241

# %% [markdown]
# # Задание 3

# %%
# Сформируйте итоговую выгрузку в формате csv (разделитель запятая), которая 

# будет содержать все объекты общепита из файла main.csv. 

# Подтяните признак сетевой/не сетевой и актуальную специализацию. 

# Отсортируйте по специализации  в алфавитном порядке.

# Внутри каждой специализации сортировка должна идти по убыванию ID. 

# Объекты у которых отсутствует специализация должны идти в начале выгрузки (и тоже по убыванию ID).

# Колонки, которые должны быть в csv файле:

# ID,Name,Address,IsNetObject,TypeObject,is_actual

# Подсказка:

# Подтягивать нужно только актуальную специализацию! Если is_actual == True

# %%
df1 = pd.read_csv('main.csv')

# %%
df1
# Out:
#           ID               Name  \
# 0      20988                ГУЗ
# 1      24828        Кафе Халяль
# 2     358126           Scarface
# 3     373052         Кулинариум
# 4     303239   One price coffee
# ...      ...                ...
# 9995  192373         Рамен Клаб
# 9996  204304         Папа Джонс
# 9997  301366           Up Sushi
# 9998  339278             Шаурма
# 9999   23511  Столовая при ММВЗ
#
#                                                 Address
# 0                  город Москва, улица Казакова, дом 15
# 1     город Москва, 8-я улица Текстильщиков, дом 5, ...
# 2     Российская Федерация, город Москва, внутригоро...
# 3     Российская Федерация, город Москва, внутригоро...
# 4     Российская Федерация, город Москва, внутригоро...
# ...                                                 ...
# 9995              город Москва, Мясницкая улица, дом 16
# 9996      город Москва, проспект Маршала Жукова, дом 59
# 9997  город Москва, город Московский, улица Москвити...
# 9998  город Москва, улица Орджоникидзе, дом 12, стро...
# 9999              город Москва, Рябиновая улица, дом 53
#
# [10000 rows x 3 columns]

# %%
df2 = pd.read_csv('net_property.csv')

# %%
df2
# Out:
#            ID IsNetObject
# 0      369614         нет
# 1      201691         нет
# 2      362705         нет
# 3      286817         нет
# 4       25950          да
# ...       ...         ...
# 12995   28474         нет
# 12996  295224         нет
# 12997  168540         нет
# 12998  366823          да
# 12999   83757         нет
#
# [13000 rows x 2 columns]

# %%
df3 = pd.read_csv('type_property.csv')

# %%
df3
# Out:
#            ID  TypeObject  is_actual
# 0      302619  закусочная       True
# 1       28573    столовая       True
# 2      373269        кафе      False
# 3       29517    столовая       True
# 4      368413        кафе      False
# ...       ...         ...        ...
# 12995  302916        кафе      False
# 12996   23238        кафе       True
# 12997  286294        кафе      False
# 12998  318855    столовая      False
# 12999  348824        кафе       True
#
# [13000 rows x 3 columns]

# %%
df3 = df3[df3['is_actual'] == True]

# %%
df4 = pd.merge(df1, df2, how = 'left')

# %%
df4
# Out:
#           ID               Name  \
# 0      20988                ГУЗ
# 1      24828        Кафе Халяль
# 2     358126           Scarface
# 3     373052         Кулинариум
# 4     303239   One price coffee
# ...      ...                ...
# 9995  192373         Рамен Клаб
# 9996  204304         Папа Джонс
# 9997  301366           Up Sushi
# 9998  339278             Шаурма
# 9999   23511  Столовая при ММВЗ
#
#                                                 Address IsNetObject
# 0                  город Москва, улица Казакова, дом 15         нет
# 1     город Москва, 8-я улица Текстильщиков, дом 5, ...         NaN
# 2     Российская Федерация, город Москва, внутригоро...         NaN
# 3     Российская Федерация, город Москва, внутригоро...         NaN
# 4     Российская Федерация, город Москва, внутригоро...         нет
# ...                                                 ...         ...
# 9995              город Москва, Мясницкая улица, дом 16         NaN
# 9996      город Москва, проспект Маршала Жукова, дом 59          да
# 9997  город Москва, город Московский, улица Москвити...         NaN
# 9998  город Москва, улица Орджоникидзе, дом 12, стро...         нет
# 9999              город Москва, Рябиновая улица, дом 53         NaN
#
# [10000 rows x 4 columns]

# %%
df5 = pd.merge(df4, df3, how = 'left')

# %%
df5
# Out:
#           ID               Name  \
# 0      20988                ГУЗ
# 1      24828        Кафе Халяль
# 2     358126           Scarface
# 3     373052         Кулинариум
# 4     303239   One price coffee
# ...      ...                ...
# 9995  192373         Рамен Клаб
# 9996  204304         Папа Джонс
# 9997  301366           Up Sushi
# 9998  339278             Шаурма
# 9999   23511  Столовая при ММВЗ
#
#                                                 Address IsNetObject  \
# 0                  город Москва, улица Казакова, дом 15         нет
# 1     город Москва, 8-я улица Текстильщиков, дом 5, ...         NaN
# 2     Российская Федерация, город Москва, внутригоро...         NaN
# 3     Российская Федерация, город Москва, внутригоро...         NaN
# 4     Российская Федерация, город Москва, внутригоро...         нет
# ...                                                 ...         ...
# 9995              город Москва, Мясницкая улица, дом 16         NaN
# 9996      город Москва, проспект Маршала Жукова, дом 59          да
# 9997  город Москва, город Московский, улица Москвити...         NaN
# 9998  город Москва, улица Орджоникидзе, дом 12, стро...         нет
# 9999              город Москва, Рябиновая улица, дом 53         NaN
#
#                              TypeObject is_actual
# 0                              столовая      True
# 1                                   NaN       NaN
# 2                                  кафе      True
# 3                                   NaN       NaN
# 4                                   NaN       NaN
# ...                                 ...       ...
# 9995                                NaN       NaN
# 9996                                NaN       NaN
# 9997                                NaN       NaN
# 9998  предприятие быстрого обслуживания      True
# 9999                           столовая      True
#
# [10000 rows x 6 columns]

# %%
# Отсортируйте по специализации  в алфавитном порядке.

# Внутри каждой специализации сортировка должна идти по убыванию ID. 

# Объекты у которых отсутствует специализация должны идти в начале выгрузки (и тоже по убыванию ID). na_position='last'

# %%
# здесь новое что параметр ascending, оказывается можно задавать каждому by:

df5.sort_values(by = ['TypeObject', 'ID'], ascending = [True, False], na_position='first')
# Out:
# C:\Users\roman\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\roman\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#           ID                                Name  \
# 4912  375956                     Крошка Картошка
# 5063  375954                                Кофе
# 7804  375834                           Донеретто
# 493   375830                              Шаурма
# 5521  375822                                Кафе
# ...      ...                                 ...
# 1317   21282                    Мед. колледж № 1
# 0      20988                                 ГУЗ
# 8837   20918  ГБОУ Школа № 1251 Учебный корпус 4
# 1382   20854                              Орандж
# 1182   19724                 КП МГУ закусочная 2
#
#                                                 Address IsNetObject  \
# 4912  город Москва, Люблинская улица, дом 169, корпус 2          да
# 5063  Российская Федерация, город Москва, внутригоро...         NaN
# 7804                 город Москва, улица Лестева, дом 6         нет
# 493   город Москва, улица Вертолётчиков, дом 2А, кор...         NaN
# 5521  Российская Федерация, город Москва, внутригоро...         NaN
# ...                                                 ...         ...
# 1317                  город Москва, Чуксин тупик, дом 6         NaN
# 0                  город Москва, улица Казакова, дом 15         нет
# 8837                город Москва, улица Алабяна, дом 15         нет
# 1382  город Москва, Подъёмная улица, дом 12, строение 1         нет
# 1182     город Москва, территория Ленинские Горы, дом 1         NaN
#
#      TypeObject is_actual
# 4912        NaN       NaN
# 5063        NaN       NaN
# 7804        NaN       NaN
# 493         NaN       NaN
# 5521        NaN       NaN
# ...         ...       ...
# 1317   столовая      True
# 0      столовая      True
# 8837   столовая      True
# 1382   столовая      True
# 1182   столовая      True
#
# [10000 rows x 6 columns]

# %%
# Колонки, которые должны быть в csv файле:

# ID,Name,Address,IsNetObject,TypeObject,is_actual

# %%
df6 = df5.sort_values(by = ['TypeObject', 'ID'], ascending = [True, False], na_position='first')

# %%
df6
# Out:
# C:\Users\roman\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\roman\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#           ID                                Name  \
# 4912  375956                     Крошка Картошка
# 5063  375954                                Кофе
# 7804  375834                           Донеретто
# 493   375830                              Шаурма
# 5521  375822                                Кафе
# ...      ...                                 ...
# 1317   21282                    Мед. колледж № 1
# 0      20988                                 ГУЗ
# 8837   20918  ГБОУ Школа № 1251 Учебный корпус 4
# 1382   20854                              Орандж
# 1182   19724                 КП МГУ закусочная 2
#
#                                                 Address IsNetObject  \
# 4912  город Москва, Люблинская улица, дом 169, корпус 2          да
# 5063  Российская Федерация, город Москва, внутригоро...         NaN
# 7804                 город Москва, улица Лестева, дом 6         нет
# 493   город Москва, улица Вертолётчиков, дом 2А, кор...         NaN
# 5521  Российская Федерация, город Москва, внутригоро...         NaN
# ...                                                 ...         ...
# 1317                  город Москва, Чуксин тупик, дом 6         NaN
# 0                  город Москва, улица Казакова, дом 15         нет
# 8837                город Москва, улица Алабяна, дом 15         нет
# 1382  город Москва, Подъёмная улица, дом 12, строение 1         нет
# 1182     город Москва, территория Ленинские Горы, дом 1         NaN
#
#      TypeObject is_actual
# 4912        NaN       NaN
# 5063        NaN       NaN
# 7804        NaN       NaN
# 493         NaN       NaN
# 5521        NaN       NaN
# ...         ...       ...
# 1317   столовая      True
# 0      столовая      True
# 8837   столовая      True
# 1382   столовая      True
# 1182   столовая      True
#
# [10000 rows x 6 columns]

# %%
df6.reset_index(drop=True)
# Out:
#           ID                                Name  \
# 0     375956                     Крошка Картошка
# 1     375954                                Кофе
# 2     375834                           Донеретто
# 3     375830                              Шаурма
# 4     375822                                Кафе
# ...      ...                                 ...
# 9995   21282                    Мед. колледж № 1
# 9996   20988                                 ГУЗ
# 9997   20918  ГБОУ Школа № 1251 Учебный корпус 4
# 9998   20854                              Орандж
# 9999   19724                 КП МГУ закусочная 2
#
#                                                 Address IsNetObject  \
# 0     город Москва, Люблинская улица, дом 169, корпус 2          да
# 1     Российская Федерация, город Москва, внутригоро...         NaN
# 2                    город Москва, улица Лестева, дом 6         нет
# 3     город Москва, улица Вертолётчиков, дом 2А, кор...         NaN
# 4     Российская Федерация, город Москва, внутригоро...         NaN
# ...                                                 ...         ...
# 9995                  город Москва, Чуксин тупик, дом 6         NaN
# 9996               город Москва, улица Казакова, дом 15         нет
# 9997                город Москва, улица Алабяна, дом 15         нет
# 9998  город Москва, Подъёмная улица, дом 12, строение 1         нет
# 9999     город Москва, территория Ленинские Горы, дом 1         NaN
#
#      TypeObject is_actual
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# ...         ...       ...
# 9995   столовая      True
# 9996   столовая      True
# 9997   столовая      True
# 9998   столовая      True
# 9999   столовая      True
#
# [10000 rows x 6 columns]

# %%
df6.columns
# Out:
# Index(['ID', 'Name', 'Address', 'IsNetObject', 'TypeObject', 'is_actual'], dtype='object')

# %%
result_task_3_from_HW_2 = df6.to_csv('result_task_3_from_HW_2.csv', index = False)

# %% [markdown]
# # Аналог merge; конкатенация датафреймов через concat

# %% [markdown]
# ## Сначала Join

# %%
df1 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер', 'Учитель'],
                    'Зарплата': [55000, 52000, 50000, 45000, 30000, 20000]})

df2 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Премия': [15000, 12000, 10000, 9000, 3000]})

df3 = pd.DataFrame({'Должность': ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Мат.помощь': [15000, 12000, 10000, 9000, 3000]})

# %%
df1.index = df1['Должность']
df1 = df1.drop('Должность', axis = 1)

# df3 понадобится немного позже:
df3.index = df3['Должность']
df3 = df3.drop('Должность', axis = 1)

# %%
df1
# Out:
#             Зарплата
# Должность
# Начальник      55000
# Советник       52000
# Эксперт        50000
# Специалист     45000
# Стажер         30000
# Учитель        20000

# %%
df2.index = df2['Должность']
df2 = df2.drop('Должность', axis = 1)

# %%
df2
# Out:
#             Премия
# Должность
# Начальник    15000
# Советник     12000
# Эксперт      10000
# Специалист    9000
# Стажер        3000

# %%
# join объединяет датафреймы автоматически по индексам, без доп.настроек

df3 = df1.join(df2)

# %%
# по умолчанию merge обдединяет how = 'inner', а у join - how = 'left'

# how{‘left’, ‘right’, ‘outer’, ‘inner’, ‘cross’}, default ‘left’

df3
# Out:
#             Зарплата   Премия
# Должность
# Начальник      55000  15000.0
# Советник       52000  12000.0
# Эксперт        50000  10000.0
# Специалист     45000   9000.0
# Стажер         30000   3000.0
# Учитель        20000      NaN

# %%
# Если есть и в первом и во втором датафрейме колонки с одинаковыми названиями:

# в функции merge - добавляется суффикс _X и _Y и выводятся обе колонки в итоговом датафрейме

# join в этом случае дает ошибку: columns overlap but no suffix specified: Index(['Должность'], dtype='object')


### в join можно передать lsuffix и rsuffix:

# %%
df1.join(df2, lsuffix = '_LEFT', rsuffix = '_RIGHT')
# Out:
#   Должность_LEFT  Зарплата Должность_RIGHT   Премия
# 0      Начальник     55000       Начальник  15000.0
# 1       Советник     52000        Советник  12000.0
# 2        Эксперт     50000         Эксперт  10000.0
# 3     Специалист     45000      Специалист   9000.0
# 4         Стажер     30000          Стажер   3000.0
# 5        Учитель     20000             NaN      NaN

# %% [markdown]
# ### Отличия merge и join -------------------------- df1.join([df2, df3])

# %%
df1
# Out:
#             Зарплата
# Должность
# Начальник      55000
# Советник       52000
# Эксперт        50000
# Специалист     45000
# Стажер         30000
# Учитель        20000

# %%
df2
# Out:
#             Премия
# Должность
# Начальник    15000
# Советник     12000
# Эксперт      10000
# Специалист    9000
# Стажер        3000

# %%
df3
# Out:
#             Мат.помощь
# Должность
# Начальник        15000
# Советник         12000
# Эксперт          10000
# Специалист        9000
# Стажер            3000

# %%
# добавляем строчку в конец:

df3.loc[ len(df3.index )] = [15000]

# %%
df3.index = ['Начальник', 'Советник', 'Эксперт', 'Специалист', 'Стажер', 'Пиждон']

# %%
df3
# Out:
#             Мат.помощь
# Начальник        15000
# Советник         12000
# Эксперт          10000
# Специалист        9000
# Стажер            3000
# Пиждон           15000

# %%
# для того, чтобы объединить сразу все df - надо передавать в join сразу лист датафреймов:

df1.join([df2, df3])
# Out:
#             Зарплата   Премия  Мат.помощь
# Должность
# Начальник    55000.0  15000.0     15000.0
# Советник     52000.0  12000.0     12000.0
# Эксперт      50000.0  10000.0     10000.0
# Специалист   45000.0   9000.0      9000.0
# Стажер       30000.0   3000.0      3000.0
# Учитель      20000.0      NaN         NaN

# %%
df1.join([df2, df3], how = 'outer')
# Out:
#             Зарплата   Премия  Мат.помощь
# Начальник    55000.0  15000.0     15000.0
# Советник     52000.0  12000.0     12000.0
# Эксперт      50000.0  10000.0     10000.0
# Специалист   45000.0   9000.0      9000.0
# Стажер       30000.0   3000.0      3000.0
# Учитель      20000.0      NaN         NaN
# Пиждон           NaN      NaN     15000.0

# %% [markdown]
# # Конкатенация  *** concat

# %%
# concat применяется когда надо к одному df пристегнуть другой df снизу

# %%
df1 = pd.DataFrame({'Должность': ['Начальник', 'Начальник2', 'Начальник3', 'Начальник4', 'Начальник5', 'Начальник6'],
                    'Зарплата': [55000, 52000, 50000, 45000, 30000, 20000]})

df2 = pd.DataFrame({'Должность': ['Зам', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Зарплата': [15000, 12000, 10000, 9000, 3000]})

# %%
df1
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1  Начальник2     52000
# 2  Начальник3     50000
# 3  Начальник4     45000
# 4  Начальник5     30000
# 5  Начальник6     20000

# %%
df2
# Out:
#     Должность  Зарплата
# 0         Зам     15000
# 1    Советник     12000
# 2     Эксперт     10000
# 3  Специалист      9000
# 4      Стажер      3000

# %%
# на языке SQL выполняется операция UNION ALL

df3 = pd.concat([df1,df2])

# %%
# индекс идет не по порядку:
df3
# Out:
#     Должность  Зарплата
# 0   Начальник     55000
# 1  Начальник2     52000
# 2  Начальник3     50000
# 3  Начальник4     45000
# 4  Начальник5     30000
# 5  Начальник6     20000
# 0         Зам     15000
# 1    Советник     12000
# 2     Эксперт     10000
# 3  Специалист      9000
# 4      Стажер      3000

# %%
# индекс идет по порядку:
df3.reset_index(drop = True)
# Out:
#      Должность  Зарплата
# 0    Начальник     55000
# 1   Начальник2     52000
# 2   Начальник3     50000
# 3   Начальник4     45000
# 4   Начальник5     30000
# 5   Начальник6     20000
# 6          Зам     15000
# 7     Советник     12000
# 8      Эксперт     10000
# 9   Специалист      9000
# 10      Стажер      3000

# %%
# Также можно еще на этапе конкатенации задать ignore_index = True:

df3 = pd.concat([df1,df2], ignore_index = True)

# %%
df3
# Out:
#      Должность  Зарплата
# 0    Начальник     55000
# 1   Начальник2     52000
# 2   Начальник3     50000
# 3   Начальник4     45000
# 4   Начальник5     30000
# 5   Начальник6     20000
# 6          Зам     15000
# 7     Советник     12000
# 8      Эксперт     10000
# 9   Специалист      9000
# 10      Стажер      3000

# %%
# Также есть возможность передавать метки keys для каждого из соединяемых датафреймов:

df3 = pd.concat([df1,df2], keys = ['Начальники', 'Кончальники'])

# %%
df3
# Out:
#                 Должность  Зарплата
# Начальники  0   Начальник     55000
#             1  Начальник2     52000
#             2  Начальник3     50000
#             3  Начальник4     45000
#             4  Начальник5     30000
#             5  Начальник6     20000
# Кончальники 0         Зам     15000
#             1    Советник     12000
#             2     Эксперт     10000
#             3  Специалист      9000
#             4      Стажер      3000

# %% [markdown]
# ### Случай когда количество колонок в двух датафреймах не совпадает:

# %%
df1 = pd.DataFrame({'Должность': ['Начальник', 'Начальник2', 'Начальник3', 'Начальник4', 'Начальник5', 'Начальник6'],
                    'Зарплата': [55000, 52000, 50000, 45000, 30000, 20000],
                    'Премия': [5500, 5200, 5000, 4500, 3000, 2000]})

df2 = pd.DataFrame({'Должность': ['Зам', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Зарплата': [15000, 12000, 10000, 9000, 3000]})

# %%
df1
# Out:
#     Должность  Зарплата  Премия
# 0   Начальник     55000    5500
# 1  Начальник2     52000    5200
# 2  Начальник3     50000    5000
# 3  Начальник4     45000    4500
# 4  Начальник5     30000    3000
# 5  Начальник6     20000    2000

# %%
df2
# Out:
#     Должность  Зарплата
# 0         Зам     15000
# 1    Советник     12000
# 2     Эксперт     10000
# 3  Специалист      9000
# 4      Стажер      3000

# %%
df3 = pd.concat([df1, df2])

# %%
# по умолчанию добавляется все существующие в датафреймах колонки:
df3
# Out:
#     Должность  Зарплата  Премия
# 0   Начальник     55000  5500.0
# 1  Начальник2     52000  5200.0
# 2  Начальник3     50000  5000.0
# 3  Начальник4     45000  4500.0
# 4  Начальник5     30000  3000.0
# 5  Начальник6     20000  2000.0
# 0         Зам     15000     NaN
# 1    Советник     12000     NaN
# 2     Эксперт     10000     NaN
# 3  Специалист      9000     NaN
# 4      Стажер      3000     NaN

# %%
df3 = pd.concat([df2, df1])

# %%
df3
# Out:
#     Должность  Зарплата  Премия
# 0         Зам     15000     NaN
# 1    Советник     12000     NaN
# 2     Эксперт     10000     NaN
# 3  Специалист      9000     NaN
# 4      Стажер      3000     NaN
# 0   Начальник     55000  5500.0
# 1  Начальник2     52000  5200.0
# 2  Начальник3     50000  5000.0
# 3  Начальник4     45000  4500.0
# 4  Начальник5     30000  3000.0
# 5  Начальник6     20000  2000.0

# %%
# чтобы не добавлять колонку надо прописать join = 'inner' (по умолчанию join = 'outer')

df3 = pd.concat([df2, df1], join = 'inner')

# %%
df3
# Out:
#     Должность  Зарплата
# 0         Зам     15000
# 1    Советник     12000
# 2     Эксперт     10000
# 3  Специалист      9000
# 4      Стажер      3000
# 0   Начальник     55000
# 1  Начальник2     52000
# 2  Начальник3     50000
# 3  Начальник4     45000
# 4  Начальник5     30000
# 5  Начальник6     20000

# %%
# Еще случай:

df1 = pd.DataFrame({'Должность': ['Начальник', 'Начальник2', 'Начальник3', 'Начальник4', 'Начальник5', 'Начальник6'],
                    'Зарплата': [55000, 52000, 50000, 45000, 30000, 20000],
                    'Премия': [5500, 5200, 5000, 4500, 3000, 2000]})

df2 = pd.DataFrame({'Должность': ['Зам', 'Советник', 'Эксперт', 'Специалист', 'Стажер'],
                    'Зарплата': [15000, 12000, 10000, 9000, 3000],
                   'Мат.помощь': [1500, 1200, 1000, 900, 300]})

# %%
pd.concat([df1, df2], ignore_index = True)
# Out:
#      Должность  Зарплата  Премия  Мат.помощь
# 0    Начальник     55000  5500.0         NaN
# 1   Начальник2     52000  5200.0         NaN
# 2   Начальник3     50000  5000.0         NaN
# 3   Начальник4     45000  4500.0         NaN
# 4   Начальник5     30000  3000.0         NaN
# 5   Начальник6     20000  2000.0         NaN
# 6          Зам     15000     NaN      1500.0
# 7     Советник     12000     NaN      1200.0
# 8      Эксперт     10000     NaN      1000.0
# 9   Специалист      9000     NaN       900.0
# 10      Стажер      3000     NaN       300.0

# %% [markdown]
# # Concat может выполнять ту же функцию что и join

# %%
df1 = pd.DataFrame({'Должность': ['Начальник', 'Начальник2', 'Начальник3', 'Начальник4', 'Начальник555', 'Начальник6'],
                    'Зарплата': [55000, 52000, 50000, 45000, 30000, 20000]
                    })

df2 = pd.DataFrame({'Должность': ['Начальник', 'Начальник2', 'Начальник3', 'Начальник4', 'Начальник5', 'Начальник6'],
                    'Премия': [55000, 52000, 50000, 45000, 30000, 20000]
                    })

# %%
df1
# Out:
#       Должность  Зарплата
# 0     Начальник     55000
# 1    Начальник2     52000
# 2    Начальник3     50000
# 3    Начальник4     45000
# 4  Начальник555     30000
# 5    Начальник6     20000

# %%
df2
# Out:
#     Должность  Премия
# 0   Начальник   55000
# 1  Начальник2   52000
# 2  Начальник3   50000
# 3  Начальник4   45000
# 4  Начальник5   30000
# 5  Начальник6   20000

# %%
# начальник555 объединился с начальником5: !!!

# дело в том, что concat производит объединение по индексам

pd.concat([df1, df2], axis = 1)
# Out:
#       Должность  Зарплата   Должность  Премия
# 0     Начальник     55000   Начальник   55000
# 1    Начальник2     52000  Начальник2   52000
# 2    Начальник3     50000  Начальник3   50000
# 3    Начальник4     45000  Начальник4   45000
# 4  Начальник555     30000  Начальник5   30000
# 5    Начальник6     20000  Начальник6   20000

# %%
# чтобы изменить эту механику (механику объединения по индексам) необходимо у конкатенируемых датафреймов задать индексы:

df1 = df1.set_index('Должность')
df2 = df2.set_index('Должность')

# %%
df1
# Out:
#               Зарплата
# Должность
# Начальник        55000
# Начальник2       52000
# Начальник3       50000
# Начальник4       45000
# Начальник555     30000
# Начальник6       20000

# %%
df2
# Out:
#             Премия
# Должность
# Начальник    55000
# Начальник2   52000
# Начальник3   50000
# Начальник4   45000
# Начальник5   30000
# Начальник6   20000

# %%
# теперь начальник555 без премии, а начальник5 без зарплаты:

pd.concat([df1, df2], axis = 1)
# Out:
#               Зарплата   Премия
# Должность
# Начальник      55000.0  55000.0
# Начальник2     52000.0  52000.0
# Начальник3     50000.0  50000.0
# Начальник4     45000.0  45000.0
# Начальник555   30000.0      NaN
# Начальник6     20000.0  20000.0
# Начальник5         NaN  30000.0

# %%
# по умолчанию join = 'outer' - по-этому привязывается всё
# если мы хотим видеть только то, что есть и в df1 и в df2 - задаем - join = 'inner'

pd.concat([df1, df2], axis = 1, join = 'inner')
# Out:
#             Зарплата  Премия
# Должность
# Начальник      55000   55000
# Начальник2     52000   52000
# Начальник3     50000   50000
# Начальник4     45000   45000
# Начальник6     20000   20000

# %%
# при заданной оси - axis = 1 мульти индекс появится в столбцах по заданию в keys:

pd.concat([df1, df2], axis = 1, join = 'inner', keys = ['Зарплаты: ', 'Премии: '])
# Out:
#            Зарплаты:  Премии:
#              Зарплата   Премия
# Должность
# Начальник       55000    55000
# Начальник2      52000    52000
# Начальник3      50000    50000
# Начальник4      45000    45000
# Начальник6      20000    20000

# %% [markdown]
# # Функция concat при работе с Сериями

# %%
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([5, 6], index=['f', 'g'])

# %%
s1
# Out:
# a    0
# b    1
# dtype: int64

# %%
s2
# Out:
# c    2
# d    3
# e    4
# dtype: int64

# %%
s3
# Out:
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1, s2, s3])
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1, s2, s3], axis = 1)
# Out:
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
# Чтобы точно значть откуда взялась какя информация - передаем параметр keys:

# axis = 1

pd.concat([s1, s2, s3], axis = 1, keys = ['Серия1', 'Серия2', 'Серия3'])
# Out:
#    Серия1  Серия2  Серия3
# a     0.0     NaN     NaN
# b     1.0     NaN     NaN
# c     NaN     2.0     NaN
# d     NaN     3.0     NaN
# e     NaN     4.0     NaN
# f     NaN     NaN     5.0
# g     NaN     NaN     6.0

# %%
# Чтобы точно значть откуда взялась какя информация - передаем параметр keys:

# axis = 0

pd.concat([s1, s2, s3], keys = ['Серия1', 'Серия2', 'Серия3'])
# Out:
# Серия1  a    0
#         b    1
# Серия2  c    2
#         d    3
#         e    4
# Серия3  f    5
#         g    6
# dtype: int64

# %%
# Та же самая запись через словарь:

pd.concat({'Серия1':s1, 'Серия2':s2, 'Серия3':s3})
# Out:
# Серия1  a    0
#         b    1
# Серия2  c    2
#         d    3
#         e    4
# Серия3  f    5
#         g    6
# dtype: int64

# %%
Продолжаем решать домашнее задание с прошлого урока.

# %% [markdown]
# # Задание 4

# %%
# Разбейте все сетевые объекты общепита со специализацией кафе на 4 группы (по количеству посадочных мест):

# 1) 0 - 5

# 2) 6 - 15 

# 3) 16 - 25

# 4) 26+

# В какой группе больше всего объектов? В ответе укажите номер группы и количество объектов в этой группе через пробел. 
# Пример ответа:

# 2 26

# %%
# Файлы скачены под соответствующими именами:

# main.csv - основная информация о предприятиях общественного питания


# net_property.csv - является ли предприятие сетевым


# seats_property.csv - количество посадочных мест


# type_property.csv - информация о специализации: столовая, закусочная, кафе, иное

# %%
df_seats = pd.read_csv('seats_property.csv')

# %%
df_type = pd.read_csv('type_property.csv')

# %%
df_net = pd.read_csv('net_property.csv')

# %%
df_main = pd.read_csv('main.csv')

# %%
# для df_net оставляем только те строки, где df_net['IsNetObject'] == 'да'

df_net = df_net[df_net['IsNetObject'] == 'да']

# %%
# мерджим df_main и новый df_net получаем df1

df1 = pd.merge(df_main, df_net, how = 'inner', on = 'ID')

pd.merge(df_main, df_net, how = 'inner', on = 'ID')
# Out:
#           ID         Name                                            Address  \
# 0     211210        Милти           город Москва, Колодезный переулок, дом 3
# 1     353273        Милти  Российская Федерация, город Москва, внутригоро...
# 2     366460        Cofix  Российская Федерация, город Москва, внутригоро...
# 3     139516     АКАДЕМИЯ     город Москва, площадь Киевского Вокзала, дом 2
# 4      97526  Бургер Кинг  Российская Федерация, город Москва, внутригоро...
# ...      ...          ...                                                ...
# 1151  210046        МУ-МУ          город Москва, Новослободская улица, дом 4
# 1152   70049          KFC       город Москва, Новоясеневский проспект, дом 1
# 1153  172655          KFC          город Москва, Измайловское шоссе, дом 69Г
# 1154  297729   Додо Пицца  Российская Федерация, город Москва, внутригоро...
# 1155  204304   Папа Джонс      город Москва, проспект Маршала Жукова, дом 59
#
#      IsNetObject
# 0             да
# 1             да
# 2             да
# 3             да
# 4             да
# ...          ...
# 1151          да
# 1152          да
# 1153          да
# 1154          да
# 1155          да
#
# [1156 rows x 4 columns]

# %%
# для df_type оставляем только те строки в которых: (df_type['TypeObject'] == 'кафе') & (df_type['is_actual'] == True)

df_type = df_type[(df_type['TypeObject'] == 'кафе') & (df_type['is_actual'] == True)]

# %%
# мержим df1 (получен на предыдущем шаге с новым df_type)

df2 = pd.merge(df1, df_type)
pd.merge(df1, df_type)
# Out:
#          ID                           Name  \
# 0    323242  МСК Московская сеть кальянных
# 1    305044                        СушиВок
# 2    298813                     Пиццетория
# 3    286093                           FARШ
# 4    340243                        Дабл Би
# ..      ...                            ...
# 136  127607               Upside Down Cake
# 137   24698                  Хинкальная №1
# 138  252171                     Teika BOOM
# 139  139871                        Николай
# 140   71756                    Шоколадница
#
#                                                Address IsNetObject TypeObject  \
# 0    Российская Федерация, город Москва, внутригоро...          да       кафе
# 1              город Москва, Хорошёвское шоссе, дом 90          да       кафе
# 2     город Москва, Дубнинская улица, дом 53, корпус 1          да       кафе
# 3    Российская Федерация, город Москва, внутригоро...          да       кафе
# 4    Российская Федерация, город Москва, внутригоро...          да       кафе
# ..                                                 ...         ...        ...
# 136              город Москва, Ярцевская улица, дом 19          да       кафе
# 137  город Москва, Старая Басманная улица, дом 7, с...          да       кафе
# 138  город Москва, поселение Московский, Киевское ш...          да       кафе
# 139  город Москва, Пятницкая улица, дом 53/18, стро...          да       кафе
# 140  город Москва, Шереметьевская улица, дом 6, кор...          да       кафе
#
#      is_actual
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# ..         ...
# 136       True
# 137       True
# 138       True
# 139       True
# 140       True
#
# [141 rows x 6 columns]

# %%
# вот это самое непонятное: (взято из предыдущей задачи вообще как было):

# сортируем значения по ID и ver_ID ascending = False

# дропаем дубликаты, оставляем только первый - а это с ver_ID == 2.

# таким образом остаются либо чистые ver_ID == 2 либо ver_ID == 1 (у которых и не было обновлений до 2)

df3 = df_seats.sort_values(by = ['ID', 'ver_ID'], ascending = False).drop_duplicates(subset = 'ID', keep = 'first')
df_seats.sort_values(by = ['ID', 'ver_ID'], ascending = False).drop_duplicates(subset = 'ID', keep = 'first')
# Out:
#            ID  SeatsCount  ver_ID
# 6693   375956           0       1
# 2158   375942           0       1
# 8637   375940          10       2
# 8218   375933           5       2
# 2212   375905          34       1
# ...       ...         ...     ...
# 1449    19681          24       1
# 5032    19678          46       1
# 10104   19657          85       2
# 3965    19627          20       2
# 673      5882          75       2
#
# [8432 rows x 3 columns]

# %%
df4 = pd.merge(df2, df3)
pd.merge(df2, df3)
# Out:
#         ID                           Name  \
# 0   323242  МСК Московская сеть кальянных
# 1   298813                     Пиццетория
# 2   340243                        Дабл Би
# 3    23734                    ШОКОЛАДНИЦА
# 4   259950                            KFC
# ..     ...                            ...
# 65   25744                     Алло Пицца
# 66  283290                    Мята Lounge
# 67  311827                      Джаганнат
# 68  359251                    Шоколадница
# 69  138495                     Хинкальная
#
#                                               Address IsNetObject TypeObject  \
# 0   Российская Федерация, город Москва, внутригоро...          да       кафе
# 1    город Москва, Дубнинская улица, дом 53, корпус 1          да       кафе
# 2   Российская Федерация, город Москва, внутригоро...          да       кафе
# 3    город Москва, Ореховый бульвар, дом 14, корпус 3          да       кафе
# 4   Российская Федерация, город Москва, внутригоро...          да       кафе
# ..                                                ...         ...        ...
# 65               город Москва, Ткацкая улица, дом 32А          да       кафе
# 66     город Москва, улица Академика Ильюшина, дом 12          да       кафе
# 67  Российская Федерация, город Москва, внутригоро...          да       кафе
# 68   город Москва, Лазоревый проезд, дом 1А, корпус 3          да       кафе
# 69   город Москва, Большая Серпуховская улица, дом 29          да       кафе
#
#     is_actual  SeatsCount  ver_ID
# 0        True          37       1
# 1        True          30       2
# 2        True          10       1
# 3        True          89       2
# 4        True          33       2
# ..        ...         ...     ...
# 65       True          35       2
# 66       True          20       1
# 67       True          25       1
# 68       True          51       2
# 69       True          23       2
#
# [70 rows x 8 columns]

# %%
# 1) 0 - 5

# 2) 6 - 15 

# 3) 16 - 25

# 4) 26+

bins = [-1, 5, 15, 25, np.inf]

pd.cut(df4['SeatsCount'], bins)
# Out:
# 0      (25.0, inf]
# 1      (25.0, inf]
# 2      (5.0, 15.0]
# 3      (25.0, inf]
# 4      (25.0, inf]
#           ...
# 65     (25.0, inf]
# 66    (15.0, 25.0]
# 67    (15.0, 25.0]
# 68     (25.0, inf]
# 69    (15.0, 25.0]
# Name: SeatsCount, Length: 70, dtype: category
# Categories (4, interval[float64, right]): [(-1.0, 5.0] < (5.0, 15.0] < (15.0, 25.0] < (25.0, inf]]

# %%
rez = pd.cut(df4['SeatsCount'], bins)

# %%
rez.value_counts()
# Out:
# (25.0, inf]     46
# (5.0, 15.0]     12
# (15.0, 25.0]    10
# (-1.0, 5.0]      2
# Name: SeatsCount, dtype: int64

# %% [markdown]
# # Задание 5

# %%
Найдите id сетевых кафе у которых отсутствует запись в (main.csv). Отсортируйте id по убыванию и загрузите их.

В вашем файле должен быть только один столбец - ID. Выгрузка в формате csv (без индекса).

В задании имеется ввиду АКТУАЛЬНЫЕ кафе =)

# %%
df_seats = pd.read_csv('seats_property.csv')

# %%
df_type = pd.read_csv('type_property.csv')

# %%
df_net = pd.read_csv('net_property.csv')

# %%
df_main = pd.read_csv('main.csv')

# %%
# фильтр только сетевые

df_net = df_net[df_net['IsNetObject'] == 'да']

# %%
# фильтр только кафе и только актуальные

# для df_type оставляем только те строки в которых: (df_type['TypeObject'] == 'кафе') & (df_type['is_actual'] == True)

df_type = df_type[(df_type['TypeObject'] == 'кафе') & (df_type['is_actual'] == True)]

# %%
df1 = pd.merge(df_main, df_type,  how = 'right')
pd.merge(df_main, df_type,  how = 'right')
# Out:
#           ID                  Name  \
# 0     282390             Salumeria
# 1     269847                   NaN
# 2     297802            Алло Пицца
# 3     197475                   NaN
# 4     325328                   NaN
# ...      ...                   ...
# 2396  250955  White Star Кузьминки
# 2397   21864                   NaN
# 2398  361696         Мистер Бургер
# 2399   23238                   NaN
# 2400  348824           Кафе Шаурма
#
#                                                 Address TypeObject  is_actual
# 0     Российская Федерация, город Москва, внутригоро...       кафе       True
# 1                                                   NaN       кафе       True
# 2     Российская Федерация, город Москва, внутригоро...       кафе       True
# 3                                                   NaN       кафе       True
# 4                                                   NaN       кафе       True
# ...                                                 ...        ...        ...
# 2396  Российская Федерация, город Москва, внутригоро...       кафе       True
# 2397                                                NaN       кафе       True
# 2398  Российская Федерация, город Москва, внутригоро...       кафе       True
# 2399                                                NaN       кафе       True
# 2400  город Москва, Дубнинская улица, дом 12Б, строе...       кафе       True
#
# [2401 rows x 5 columns]

# %%
df2 = pd.merge(df1, df_net,  how = 'inner')
pd.merge(df1, df_net,  how = 'inner')
# Out:
#          ID                        Name  \
# 0    297802                  Алло Пицца
# 1    302226                    КОФЕПОРТ
# 2    305044                     СушиВок
# 3    340243                     Дабл Би
# 4    288642  Кофемания на Садовническая
# ..      ...                         ...
# 271  192911                  Прайм стар
# 272   22375                      Кружка
# 273   24342                         NaN
# 274  359251                 Шоколадница
# 275  297100                    Брусника
#
#                                                Address TypeObject  is_actual  \
# 0    Российская Федерация, город Москва, внутригоро...       кафе       True
# 1    Российская Федерация, город Москва, внутригоро...       кафе       True
# 2              город Москва, Хорошёвское шоссе, дом 90       кафе       True
# 3    Российская Федерация, город Москва, внутригоро...       кафе       True
# 4    город Москва, Садовническая улица, дом 82, стр...       кафе       True
# ..                                                 ...        ...        ...
# 271  город Москва, Нижний Сусальный переулок, дом 5...       кафе       True
# 272  город Москва, Мясницкая улица, дом 32, строение 1       кафе       True
# 273                                                NaN       кафе       True
# 274   город Москва, Лазоревый проезд, дом 1А, корпус 3       кафе       True
# 275  Российская Федерация, город Москва, внутригоро...       кафе       True
#
#     IsNetObject
# 0            да
# 1            да
# 2            да
# 3            да
# 4            да
# ..          ...
# 271          да
# 272          да
# 273          да
# 274          да
# 275          да
#
# [276 rows x 6 columns]

# %%
df2['ID'][df2['Name'].isna()]
# Out:
# 6      291129
# 8      130996
# 9      166982
# 10      24317
# 11     286892
#         ...
# 264    214292
# 266    326862
# 267     84922
# 268    223188
# 273     24342
# Name: ID, Length: 135, dtype: int64

# %%
df3 = df2['ID'][df2['Name'].isna()].drop_duplicates(keep = 'first')
df2['ID'][df2['Name'].isna()].drop_duplicates(keep = 'first')
# Out:
# 6      291129
# 8      130996
# 9      166982
# 10      24317
# 11     286892
#         ...
# 264    214292
# 266    326862
# 267     84922
# 268    223188
# 273     24342
# Name: ID, Length: 135, dtype: int64

# %%
df4 = df3.sort_values(ascending = False)
df3.sort_values(ascending = False)
# Out:
# 221    374676
# 111    374275
# 95     374114
# 170    371701
# 263    367930
#         ...
# 127     22089
# 103     22005
# 169     21732
# 255     20497
# 17      19882
# Name: ID, Length: 135, dtype: int64

# %%
df4.to_csv('result_task_6_without_index.csv', index = False)

# %% [markdown]
# # Задание 6

# %%
Есть два списка - адреса и id объектов. 

'Список_ID.xlsx'

'Список_адресов.xlsx'


Подтяните для них информацию:
    
1) признак сетевой/не сетевой. Если признака нет, то оставьте поле пустым.

2) актуальную специализацию. Если ее нет, то напишите 'отсутствует'

3) последнюю информацию о числе посадочных мест. Если мест нет, то укажите 0.

Отсортируйте объекты в порядке убывания ID. Колонки переведите на русский язык т.к. коллеги не понимают англ. язык:

Ид,Наименование,Адрес,Сетевой?,Специализация,КоличМест

Загрузите файл в формате csv (разделитель запятая, без индекса).

# %%
df1 = pd.read_excel('Список_ID.xlsx')

# %%
df2 = pd.read_excel('Список_адресов.xlsx', sheet_name='Sheet1')

# %%
df1
# Out:
#    Список предприятий попадающих под проверку
# 0                                          ID
# 1                                       20821
# 2                                      172247
# 3                                      137290
# 4                                       29194
# 5                                      141704
# 6                                      347136
# 7                                      260793
# 8                                      302646
# 9                                      163518
# 10                                     361230
# 11                                     365655
# 12                                     И29194

# %%
df1.columns = ['ID']

# %%
df1 = df1[df1.index >0]

# %%
df1
# Out:
#         ID
# 1    20821
# 2   172247
# 3   137290
# 4    29194
# 5   141704
# 6   347136
# 7   260793
# 8   302646
# 9   163518
# 10  361230
# 11  365655
# 12  И29194

# %%
# проверяем есть ли такой индекс в df_main как 29194, а это №12 только без буквы И - надо заменить вестимо?
(df_main['ID']. eq(29194)).any ()
# Out:
# True

# %%
df1 = df1.replace('И29194', 29194)

# %%
df1
# Out:
#         ID
# 1    20821
# 2   172247
# 3   137290
# 4    29194
# 5   141704
# 6   347136
# 7   260793
# 8   302646
# 9   163518
# 10  361230
# 11  365655
# 12   29194

# %%
df2
# Out:
#    Список адресов по которым будет выполнена проверка юридическим отделом
# 0                                                 NaN
# 1                город Москва, улица Арбат, дом 55/32
# 2           город Москва, Салтыковская улица, дом 15Г
# 3   город Москва, Пресненская набережная, дом 2, п...
# 4   Российская Федерация, город Москва, внутригоро...
# 5   город Москва, Ленинградский проспект, дом 31А,...
# 6     город Москва, Ярцевская улица, дом 34, корпус 2
# 7   Российская Федерация, город Москва, внутригоро...
# 8   Российская Федерация, город Москва, внутригоро...
# 9   Российская Федерация, город Москва, внутригоро...
# 10      город Москва, улица Алабяна, дом 13, корпус 2
# 11  Российская Федерация, город Москва, внутригоро...
# 12  Российская Федерация, город Москва, внутригоро...
# 13         город Москва, проспект Вернадского, дом 53
# 14  город Москва, Гостиничный проезд, дом 6, корпус 2
# 15  город Москва, город Московский, Радужная улица...
# 16               город Москва, Ладожская улица, дом 5
# 17  город Москва, Большая Садовая улица, дом 5, ко...
# 18  Российская Федерация, город Москва, внутригоро...
# 19           город Москва, Коровинское шоссе, дом 24А
# 20  город Москва, Большая Черкизовская улица, дом 30Б

# %%
df2 = df2[df2.index >0]

# %%
df2
# Out:
#    Список адресов по которым будет выполнена проверка юридическим отделом
# 1                город Москва, улица Арбат, дом 55/32
# 2           город Москва, Салтыковская улица, дом 15Г
# 3   город Москва, Пресненская набережная, дом 2, п...
# 4   Российская Федерация, город Москва, внутригоро...
# 5   город Москва, Ленинградский проспект, дом 31А,...
# 6     город Москва, Ярцевская улица, дом 34, корпус 2
# 7   Российская Федерация, город Москва, внутригоро...
# 8   Российская Федерация, город Москва, внутригоро...
# 9   Российская Федерация, город Москва, внутригоро...
# 10      город Москва, улица Алабяна, дом 13, корпус 2
# 11  Российская Федерация, город Москва, внутригоро...
# 12  Российская Федерация, город Москва, внутригоро...
# 13         город Москва, проспект Вернадского, дом 53
# 14  город Москва, Гостиничный проезд, дом 6, корпус 2
# 15  город Москва, город Московский, Радужная улица...
# 16               город Москва, Ладожская улица, дом 5
# 17  город Москва, Большая Садовая улица, дом 5, ко...
# 18  Российская Федерация, город Москва, внутригоро...
# 19           город Москва, Коровинское шоссе, дом 24А
# 20  город Москва, Большая Черкизовская улица, дом 30Б

# %%
df_seats = pd.read_csv('seats_property.csv')

# %%
df_type = pd.read_csv('type_property.csv')

# %%
df_net = pd.read_csv('net_property.csv')

# %%
df_main = pd.read_csv('main.csv')

# %%
df_main.head(2)
# Out:
#       ID         Name                                            Address
# 0  20988          ГУЗ               город Москва, улица Казакова, дом 15
# 1  24828  Кафе Халяль  город Москва, 8-я улица Текстильщиков, дом 5, ...

# %%
df_id_merge_main = pd.merge(df1, df_main, how = 'inner')
pd.merge(df1, df_main, how = 'inner')
# Out:
#         ID                Name  \
# 0    20821             Теремок
# 1   172247  Кафетерий AB Daily
# 2   137290      Домино'с Пицца
# 3    29194     ГБОУ школа №236
# 4    29194     ГБОУ школа №236
# 5   141704       Столичный паб
# 6   347136         Правда кофе
# 7   260793       Место Варенья
# 8   302646             Просвет
# 9   163518          Додо Пицца
# 10  361230        Столовая ЗВИ
# 11  365655          Буфет-обед
#
#                                               Address
# 0                город Москва, Ладожская улица, дом 5
# 1   город Москва, Большая Садовая улица, дом 5, ко...
# 2   Российская Федерация, город Москва, внутригоро...
# 3            город Москва, Коровинское шоссе, дом 24А
# 4            город Москва, Коровинское шоссе, дом 24А
# 5   город Москва, Большая Черкизовская улица, дом 30Б
# 6   город Москва, Дмитровское шоссе, дом 73, строе...
# 7   город Москва, внутригородская территория муниц...
# 8   Российская Федерация, город Москва, внутригоро...
# 9               город Москва, Пятницкое шоссе, дом 21
# 10  город Москва, Партийный переулок, дом 1, корпу...
# 11  Российская Федерация, город Москва, внутригоро...

# %%
df_adress_merge_main = pd.merge(df2, df_main, how = 'inner', left_on = 'Список адресов по которым будет выполнена проверка юридическим отделом', right_on = 'Address')
pd.merge(df2, df_main, how = 'inner', left_on = 'Список адресов по которым будет выполнена проверка юридическим отделом', right_on = 'Address')
# Out:
#    Список адресов по которым будет выполнена проверка юридическим отделом  \
# 0                город Москва, улица Арбат, дом 55/32
# 1           город Москва, Салтыковская улица, дом 15Г
# 2   город Москва, Пресненская набережная, дом 2, п...
# 3   город Москва, Пресненская набережная, дом 2, п...
# 4   город Москва, Пресненская набережная, дом 2, п...
# ..                                                ...
# 72  Российская Федерация, город Москва, внутригоро...
# 73  Российская Федерация, город Москва, внутригоро...
# 74           город Москва, Коровинское шоссе, дом 24А
# 75  город Москва, Большая Черкизовская улица, дом 30Б
# 76  город Москва, Большая Черкизовская улица, дом 30Б
#
#         ID             Name                                            Address
# 0   127987            Белый               город Москва, улица Арбат, дом 55/32
# 1    73438     Ганс и Марта          город Москва, Салтыковская улица, дом 15Г
# 2   367328       Чебурешная  город Москва, Пресненская набережная, дом 2, п...
# 3   322377    Star hit Cafe  город Москва, Пресненская набережная, дом 2, п...
# 4   190928   EZO Хинкальная  город Москва, Пресненская набережная, дом 2, п...
# ..     ...              ...                                                ...
# 72  332332    DO BRO coffee  Российская Федерация, город Москва, внутригоро...
# 73  372752           ШАУРМА  Российская Федерация, город Москва, внутригоро...
# 74   29194  ГБОУ школа №236           город Москва, Коровинское шоссе, дом 24А
# 75  174038       Додо Пицца  город Москва, Большая Черкизовская улица, дом 30Б
# 76  141704    Столичный паб  город Москва, Большая Черкизовская улица, дом 30Б
#
# [77 rows x 4 columns]

# %%
df_adress_merge_main[df_adress_merge_main.duplicated(subset = 'ID')]
# Out:
# Empty DataFrame
# Columns: [Список адресов по которым будет выполнена проверка юридическим отделом, ID, Name, Address]
# Index: []

# %%
df_adress_merge_main = df_adress_merge_main.drop('Список адресов по которым будет выполнена проверка юридическим отделом', axis = 1)

# %%
df_adress_merge_main
# Out:
#         ID             Name                                            Address
# 0   127987            Белый               город Москва, улица Арбат, дом 55/32
# 1    73438     Ганс и Марта          город Москва, Салтыковская улица, дом 15Г
# 2   367328       Чебурешная  город Москва, Пресненская набережная, дом 2, п...
# 3   322377    Star hit Cafe  город Москва, Пресненская набережная, дом 2, п...
# 4   190928   EZO Хинкальная  город Москва, Пресненская набережная, дом 2, п...
# ..     ...              ...                                                ...
# 72  332332    DO BRO coffee  Российская Федерация, город Москва, внутригоро...
# 73  372752           ШАУРМА  Российская Федерация, город Москва, внутригоро...
# 74   29194  ГБОУ школа №236           город Москва, Коровинское шоссе, дом 24А
# 75  174038       Додо Пицца  город Москва, Большая Черкизовская улица, дом 30Б
# 76  141704    Столичный паб  город Москва, Большая Черкизовская улица, дом 30Б
#
# [77 rows x 3 columns]

# %%
df_rez = pd.concat([df_id_merge_main, df_adress_merge_main], ignore_index=True)
pd.concat([df_id_merge_main, df_adress_merge_main], ignore_index=True)
# Out:
#         ID                Name  \
# 0    20821             Теремок
# 1   172247  Кафетерий AB Daily
# 2   137290      Домино'с Пицца
# 3    29194     ГБОУ школа №236
# 4    29194     ГБОУ школа №236
# ..     ...                 ...
# 84  332332       DO BRO coffee
# 85  372752              ШАУРМА
# 86   29194     ГБОУ школа №236
# 87  174038          Додо Пицца
# 88  141704       Столичный паб
#
#                                               Address
# 0                город Москва, Ладожская улица, дом 5
# 1   город Москва, Большая Садовая улица, дом 5, ко...
# 2   Российская Федерация, город Москва, внутригоро...
# 3            город Москва, Коровинское шоссе, дом 24А
# 4            город Москва, Коровинское шоссе, дом 24А
# ..                                                ...
# 84  Российская Федерация, город Москва, внутригоро...
# 85  Российская Федерация, город Москва, внутригоро...
# 86           город Москва, Коровинское шоссе, дом 24А
# 87  город Москва, Большая Черкизовская улица, дом 30Б
# 88  город Москва, Большая Черкизовская улица, дом 30Б
#
# [89 rows x 3 columns]

# %%
# фильтр только актуальные

# для df_type оставляем только те строки в которых: (df_type['is_actual'] == True)

df_type = df_type[(df_type['is_actual'] == True)]
df_type[(df_type['is_actual'] == True)]
# Out:
#            ID                         TypeObject  is_actual
# 0      302619                         закусочная       True
# 1       28573                           столовая       True
# 3       29517                           столовая       True
# 5      331204  предприятие быстрого обслуживания       True
# 6      140502                           столовая       True
# ...       ...                                ...        ...
# 12991  361696                               кафе       True
# 12992  151866                                бар       True
# 12993   27288                           ресторан       True
# 12996   23238                               кафе       True
# 12999  348824                               кафе       True
#
# [6585 rows x 3 columns]

# %%
# вот это самое непонятное: (взято из предыдущей задачи вообще как было):

# сортируем значения по ID и ver_ID ascending = False

# дропаем дубликаты, оставляем только первый - а это с ver_ID == 2.

# таким образом остаются либо чистые ver_ID == 2 либо ver_ID == 1 (у которых и не было обновлений до 2)

df_seats_ver_ID = df_seats.sort_values(by = ['ID', 'ver_ID'], ascending = False).drop_duplicates(subset = 'ID', keep = 'first')
df_seats.sort_values(by = ['ID', 'ver_ID'], ascending = False).drop_duplicates(subset = 'ID', keep = 'first')
# Out:
#            ID  SeatsCount  ver_ID
# 6693   375956           0       1
# 2158   375942           0       1
# 8637   375940          10       2
# 8218   375933           5       2
# 2212   375905          34       1
# ...       ...         ...     ...
# 1449    19681          24       1
# 5032    19678          46       1
# 10104   19657          85       2
# 3965    19627          20       2
# 673      5882          75       2
#
# [8432 rows x 3 columns]

# %%
df_net
# Out:
#            ID IsNetObject
# 0      369614         нет
# 1      201691         нет
# 2      362705         нет
# 3      286817         нет
# 4       25950          да
# ...       ...         ...
# 12995   28474         нет
# 12996  295224         нет
# 12997  168540         нет
# 12998  366823          да
# 12999   83757         нет
#
# [13000 rows x 2 columns]

# %%
# 1) признак сетевой/не сетевой. Если признака нет, то оставьте поле пустым.

df_rez_merge_net = pd.merge(df_rez, df_net, how = 'left')
pd.merge(df_rez, df_net, how = 'left')
# Out:
#         ID                Name  \
# 0    20821             Теремок
# 1   172247  Кафетерий AB Daily
# 2   137290      Домино'с Пицца
# 3    29194     ГБОУ школа №236
# 4    29194     ГБОУ школа №236
# ..     ...                 ...
# 84  332332       DO BRO coffee
# 85  372752              ШАУРМА
# 86   29194     ГБОУ школа №236
# 87  174038          Додо Пицца
# 88  141704       Столичный паб
#
#                                               Address IsNetObject
# 0                город Москва, Ладожская улица, дом 5          да
# 1   город Москва, Большая Садовая улица, дом 5, ко...         NaN
# 2   Российская Федерация, город Москва, внутригоро...          да
# 3            город Москва, Коровинское шоссе, дом 24А         нет
# 4            город Москва, Коровинское шоссе, дом 24А         нет
# ..                                                ...         ...
# 84  Российская Федерация, город Москва, внутригоро...         NaN
# 85  Российская Федерация, город Москва, внутригоро...         нет
# 86           город Москва, Коровинское шоссе, дом 24А         нет
# 87  город Москва, Большая Черкизовская улица, дом 30Б          да
# 88  город Москва, Большая Черкизовская улица, дом 30Б         нет
#
# [89 rows x 4 columns]

# %%
# 2) актуальную специализацию. Если ее нет, то напишите 'отсутствует'

df_rez_2 = pd.merge(df_rez_merge_net, df_type, how = 'left')

pd.merge(df_rez_merge_net, df_type, how = 'left')
# Out:
#         ID                Name  \
# 0    20821             Теремок
# 1   172247  Кафетерий AB Daily
# 2   137290      Домино'с Пицца
# 3    29194     ГБОУ школа №236
# 4    29194     ГБОУ школа №236
# ..     ...                 ...
# 84  332332       DO BRO coffee
# 85  372752              ШАУРМА
# 86   29194     ГБОУ школа №236
# 87  174038          Додо Пицца
# 88  141704       Столичный паб
#
#                                               Address IsNetObject  \
# 0                город Москва, Ладожская улица, дом 5          да
# 1   город Москва, Большая Садовая улица, дом 5, ко...         NaN
# 2   Российская Федерация, город Москва, внутригоро...          да
# 3            город Москва, Коровинское шоссе, дом 24А         нет
# 4            город Москва, Коровинское шоссе, дом 24А         нет
# ..                                                ...         ...
# 84  Российская Федерация, город Москва, внутригоро...         NaN
# 85  Российская Федерация, город Москва, внутригоро...         нет
# 86           город Москва, Коровинское шоссе, дом 24А         нет
# 87  город Москва, Большая Черкизовская улица, дом 30Б          да
# 88  город Москва, Большая Черкизовская улица, дом 30Б         нет
#
#                            TypeObject is_actual
# 0                                 NaN       NaN
# 1                                 NaN       NaN
# 2   предприятие быстрого обслуживания      True
# 3                                 NaN       NaN
# 4                                 NaN       NaN
# ..                                ...       ...
# 84                                NaN       NaN
# 85                                NaN       NaN
# 86                                NaN       NaN
# 87                               кафе      True
# 88                                NaN       NaN
#
# [89 rows x 6 columns]

# %%
df_rez_2['TypeObject'] = df_rez_2['TypeObject'].fillna('отсутствует')

# %%
df_rez_2
# Out:
#         ID                Name  \
# 0    20821             Теремок
# 1   172247  Кафетерий AB Daily
# 2   137290      Домино'с Пицца
# 3    29194     ГБОУ школа №236
# 4    29194     ГБОУ школа №236
# ..     ...                 ...
# 84  332332       DO BRO coffee
# 85  372752              ШАУРМА
# 86   29194     ГБОУ школа №236
# 87  174038          Додо Пицца
# 88  141704       Столичный паб
#
#                                               Address IsNetObject  \
# 0                город Москва, Ладожская улица, дом 5          да
# 1   город Москва, Большая Садовая улица, дом 5, ко...         NaN
# 2   Российская Федерация, город Москва, внутригоро...          да
# 3            город Москва, Коровинское шоссе, дом 24А         нет
# 4            город Москва, Коровинское шоссе, дом 24А         нет
# ..                                                ...         ...
# 84  Российская Федерация, город Москва, внутригоро...         NaN
# 85  Российская Федерация, город Москва, внутригоро...         нет
# 86           город Москва, Коровинское шоссе, дом 24А         нет
# 87  город Москва, Большая Черкизовская улица, дом 30Б          да
# 88  город Москва, Большая Черкизовская улица, дом 30Б         нет
#
#                            TypeObject is_actual
# 0                         отсутствует       NaN
# 1                         отсутствует       NaN
# 2   предприятие быстрого обслуживания      True
# 3                         отсутствует       NaN
# 4                         отсутствует       NaN
# ..                                ...       ...
# 84                        отсутствует       NaN
# 85                        отсутствует       NaN
# 86                        отсутствует       NaN
# 87                               кафе      True
# 88                        отсутствует       NaN
#
# [89 rows x 6 columns]

# %%
# 3) последнюю информацию о числе посадочных мест. Если мест нет, то укажите 0.


df_rez_3 = pd.merge(df_rez_2, df_seats_ver_ID, how = 'left')
pd.merge(df_rez_2, df_seats_ver_ID, how = 'left')
# Out:
#         ID                Name  \
# 0    20821             Теремок
# 1   172247  Кафетерий AB Daily
# 2   137290      Домино'с Пицца
# 3    29194     ГБОУ школа №236
# 4    29194     ГБОУ школа №236
# ..     ...                 ...
# 84  332332       DO BRO coffee
# 85  372752              ШАУРМА
# 86   29194     ГБОУ школа №236
# 87  174038          Додо Пицца
# 88  141704       Столичный паб
#
#                                               Address IsNetObject  \
# 0                город Москва, Ладожская улица, дом 5          да
# 1   город Москва, Большая Садовая улица, дом 5, ко...         NaN
# 2   Российская Федерация, город Москва, внутригоро...          да
# 3            город Москва, Коровинское шоссе, дом 24А         нет
# 4            город Москва, Коровинское шоссе, дом 24А         нет
# ..                                                ...         ...
# 84  Российская Федерация, город Москва, внутригоро...         NaN
# 85  Российская Федерация, город Москва, внутригоро...         нет
# 86           город Москва, Коровинское шоссе, дом 24А         нет
# 87  город Москва, Большая Черкизовская улица, дом 30Б          да
# 88  город Москва, Большая Черкизовская улица, дом 30Б         нет
#
#                            TypeObject is_actual  SeatsCount  ver_ID
# 0                         отсутствует       NaN         NaN     NaN
# 1                         отсутствует       NaN         NaN     NaN
# 2   предприятие быстрого обслуживания      True         NaN     NaN
# 3                         отсутствует       NaN         NaN     NaN
# 4                         отсутствует       NaN         NaN     NaN
# ..                                ...       ...         ...     ...
# 84                        отсутствует       NaN        13.0     2.0
# 85                        отсутствует       NaN         NaN     NaN
# 86                        отсутствует       NaN         NaN     NaN
# 87                               кафе      True         6.0     1.0
# 88                        отсутствует       NaN        30.0     1.0
#
# [89 rows x 8 columns]

# %%
df_rez_3['SeatsCount'] = df_rez_3['SeatsCount'].fillna(0)

# %%
df_rez_3
# Out:
#         ID                Name  \
# 0    20821             Теремок
# 1   172247  Кафетерий AB Daily
# 2   137290      Домино'с Пицца
# 3    29194     ГБОУ школа №236
# 4    29194     ГБОУ школа №236
# ..     ...                 ...
# 84  332332       DO BRO coffee
# 85  372752              ШАУРМА
# 86   29194     ГБОУ школа №236
# 87  174038          Додо Пицца
# 88  141704       Столичный паб
#
#                                               Address IsNetObject  \
# 0                город Москва, Ладожская улица, дом 5          да
# 1   город Москва, Большая Садовая улица, дом 5, ко...         NaN
# 2   Российская Федерация, город Москва, внутригоро...          да
# 3            город Москва, Коровинское шоссе, дом 24А         нет
# 4            город Москва, Коровинское шоссе, дом 24А         нет
# ..                                                ...         ...
# 84  Российская Федерация, город Москва, внутригоро...         NaN
# 85  Российская Федерация, город Москва, внутригоро...         нет
# 86           город Москва, Коровинское шоссе, дом 24А         нет
# 87  город Москва, Большая Черкизовская улица, дом 30Б          да
# 88  город Москва, Большая Черкизовская улица, дом 30Б         нет
#
#                            TypeObject is_actual  SeatsCount  ver_ID
# 0                         отсутствует       NaN         0.0     NaN
# 1                         отсутствует       NaN         0.0     NaN
# 2   предприятие быстрого обслуживания      True         0.0     NaN
# 3                         отсутствует       NaN         0.0     NaN
# 4                         отсутствует       NaN         0.0     NaN
# ..                                ...       ...         ...     ...
# 84                        отсутствует       NaN        13.0     2.0
# 85                        отсутствует       NaN         0.0     NaN
# 86                        отсутствует       NaN         0.0     NaN
# 87                               кафе      True         6.0     1.0
# 88                        отсутствует       NaN        30.0     1.0
#
# [89 rows x 8 columns]

# %%
df_rez_4 = df_rez_3.reindex(['ID', 'Name', 'Address', 'IsNetObject', 'TypeObject', 'SeatsCount'], axis = 1)

# %%
df_rez_4.columns
# Out:
# Index(['ID', 'Name', 'Address', 'IsNetObject', 'TypeObject', 'SeatsCount'], dtype='object')

# %%
df_rez_4.columns = ['Ид', 'Наименование', 'Адрес', 'Сетевой?', 'Специализация', 'КоличМест']

# %%
df_rez_4.sort_values(by = 'Ид', ascending = False)
# Out:
#         Ид        Наименование  \
# 85  372752              ШАУРМА
# 65  369518        Чайхана УМИД
# 32  367457        Stars Coffee
# 14  367328          Чебурешная
# 72  365834         Кофестанция
# ..     ...                 ...
# 53   25007         Шоколадница
# 66   24219        Кафе «Чашки»
# 78   20821             Теремок
# 0    20821             Теремок
# 75   20123  Кафе «Дарума суши»
#
#                                                 Адрес Сетевой? Специализация  \
# 85  Российская Федерация, город Москва, внутригоро...      нет   отсутствует
# 65    город Москва, Ярцевская улица, дом 34, корпус 2      нет   отсутствует
# 32  город Москва, Пресненская набережная, дом 2, п...      NaN   отсутствует
# 14  город Москва, Пресненская набережная, дом 2, п...      NaN          кафе
# 72  Российская Федерация, город Москва, внутригоро...      нет   отсутствует
# ..                                                ...      ...           ...
# 53  Российская Федерация, город Москва, внутригоро...       да   отсутствует
# 66  Российская Федерация, город Москва, внутригоро...      NaN   отсутствует
# 78               город Москва, Ладожская улица, дом 5       да   отсутствует
# 0                город Москва, Ладожская улица, дом 5       да   отсутствует
# 75         город Москва, проспект Вернадского, дом 53      нет          кафе
#
#     КоличМест
# 85        0.0
# 65        0.0
# 32        0.0
# 14        0.0
# 72        9.0
# ..        ...
# 53        0.0
# 66        0.0
# 78        0.0
# 0         0.0
# 75       37.0
#
# [89 rows x 6 columns]

# %%
df_rez_5 = df_rez_4.sort_values(by = 'Ид', ascending = False)

# %%
df_rez_5
# Out:
#         Ид        Наименование  \
# 85  372752              ШАУРМА
# 65  369518        Чайхана УМИД
# 32  367457        Stars Coffee
# 14  367328          Чебурешная
# 72  365834         Кофестанция
# ..     ...                 ...
# 56   27010             Премьер
# 53   25007         Шоколадница
# 66   24219        Кафе «Чашки»
# 78   20821             Теремок
# 75   20123  Кафе «Дарума суши»
#
#                                                 Адрес Сетевой? Специализация  \
# 85  Российская Федерация, город Москва, внутригоро...      нет   отсутствует
# 65    город Москва, Ярцевская улица, дом 34, корпус 2      нет   отсутствует
# 32  город Москва, Пресненская набережная, дом 2, п...      NaN   отсутствует
# 14  город Москва, Пресненская набережная, дом 2, п...      NaN          кафе
# 72  Российская Федерация, город Москва, внутригоро...      нет   отсутствует
# ..                                                ...      ...           ...
# 56  город Москва, Ленинградский проспект, дом 31А,...      нет      ресторан
# 53  Российская Федерация, город Москва, внутригоро...       да   отсутствует
# 66  Российская Федерация, город Москва, внутригоро...      NaN   отсутствует
# 78               город Москва, Ладожская улица, дом 5       да   отсутствует
# 75         город Москва, проспект Вернадского, дом 53      нет          кафе
#
#     КоличМест
# 85        0.0
# 65        0.0
# 32        0.0
# 14        0.0
# 72        9.0
# ..        ...
# 56       83.0
# 53        0.0
# 66        0.0
# 78        0.0
# 75       37.0
#
# [83 rows x 6 columns]

# %%
df_rez_5 = df_rez_5.drop_duplicates(subset = 'Ид')

# %%
df_rez_5
# Out:
#         Ид        Наименование  \
# 85  372752              ШАУРМА
# 65  369518        Чайхана УМИД
# 32  367457        Stars Coffee
# 14  367328          Чебурешная
# 72  365834         Кофестанция
# ..     ...                 ...
# 56   27010             Премьер
# 53   25007         Шоколадница
# 66   24219        Кафе «Чашки»
# 78   20821             Теремок
# 75   20123  Кафе «Дарума суши»
#
#                                                 Адрес Сетевой? Специализация  \
# 85  Российская Федерация, город Москва, внутригоро...      нет   отсутствует
# 65    город Москва, Ярцевская улица, дом 34, корпус 2      нет   отсутствует
# 32  город Москва, Пресненская набережная, дом 2, п...      NaN   отсутствует
# 14  город Москва, Пресненская набережная, дом 2, п...      NaN          кафе
# 72  Российская Федерация, город Москва, внутригоро...      нет   отсутствует
# ..                                                ...      ...           ...
# 56  город Москва, Ленинградский проспект, дом 31А,...      нет      ресторан
# 53  Российская Федерация, город Москва, внутригоро...       да   отсутствует
# 66  Российская Федерация, город Москва, внутригоро...      NaN   отсутствует
# 78               город Москва, Ладожская улица, дом 5       да   отсутствует
# 75         город Москва, проспект Вернадского, дом 53      нет          кафе
#
#     КоличМест
# 85        0.0
# 65        0.0
# 32        0.0
# 14        0.0
# 72        9.0
# ..        ...
# 56       83.0
# 53        0.0
# 66        0.0
# 78        0.0
# 75       37.0
#
# [83 rows x 6 columns]

# %%
df_rez_5.to_csv('task6.csv', index = False)

# %% [markdown]
# # Задание 7

# %%
# сколько всего мест у общепита по адресу просп. Вернадского 86А

# %%
df_seats = pd.read_csv('seats_property.csv')

df_type = pd.read_csv('type_property.csv')

df_net = pd.read_csv('net_property.csv')

df_main = pd.read_csv('main.csv')

# %%
df_main
# Out:
#           ID                         Name  \
# 327   151596                      KVARTAL
# 2889  365140                   СИНЕМАСТАР
# 3781  262639                Star Hit cafe
# 4869  368180             One Price COFFEE
# 5913  361504                 Чистая линия
# 6295  198194                   Чайхона №1
# 6321  353516        О ХОТДОГ Даниель кафе
# 6374  134638                ПБО «Теремок»
# 6574  354593                  Bubbleology
# 7660  352541                   ХАВЧИК ТУТ
# 7674  134633                     ВОКМАНИЯ
# 9045  218279             Sushi store Суши
# 9202  298228                   BB&BURGERS
# 9551  285291  SHAN SHAN Вьетнамская кухня
#
#                                                 Address
# 327         город Москва, проспект Вернадского, дом 86А
# 2889        город Москва, проспект Вернадского, дом 86А
# 3781        город Москва, проспект Вернадского, дом 86А
# 4869        город Москва, проспект Вернадского, дом 86А
# 5913        город Москва, проспект Вернадского, дом 86А
# 6295        город Москва, проспект Вернадского, дом 86А
# 6321        город Москва, проспект Вернадского, дом 86А
# 6374        город Москва, проспект Вернадского, дом 86А
# 6574  Российская Федерация, город Москва, внутригоро...
# 7660        город Москва, проспект Вернадского, дом 86А
# 7674        город Москва, проспект Вернадского, дом 86А
# 9045        город Москва, проспект Вернадского, дом 86А
# 9202        город Москва, проспект Вернадского, дом 86А
# 9551  Российская Федерация, город Москва, внутригоро...

# %%
df_main = df_main[df_main['Address'].str.contains('Вернадского')]

# %%
df_main
# Out:
#           ID                         Name  \
# 327   151596                      KVARTAL
# 2889  365140                   СИНЕМАСТАР
# 3781  262639                Star Hit cafe
# 4869  368180             One Price COFFEE
# 5913  361504                 Чистая линия
# 6295  198194                   Чайхона №1
# 6321  353516        О ХОТДОГ Даниель кафе
# 6374  134638                ПБО «Теремок»
# 6574  354593                  Bubbleology
# 7660  352541                   ХАВЧИК ТУТ
# 7674  134633                     ВОКМАНИЯ
# 9045  218279             Sushi store Суши
# 9202  298228                   BB&BURGERS
# 9551  285291  SHAN SHAN Вьетнамская кухня
#
#                                                 Address
# 327         город Москва, проспект Вернадского, дом 86А
# 2889        город Москва, проспект Вернадского, дом 86А
# 3781        город Москва, проспект Вернадского, дом 86А
# 4869        город Москва, проспект Вернадского, дом 86А
# 5913        город Москва, проспект Вернадского, дом 86А
# 6295        город Москва, проспект Вернадского, дом 86А
# 6321        город Москва, проспект Вернадского, дом 86А
# 6374        город Москва, проспект Вернадского, дом 86А
# 6574  Российская Федерация, город Москва, внутригоро...
# 7660        город Москва, проспект Вернадского, дом 86А
# 7674        город Москва, проспект Вернадского, дом 86А
# 9045        город Москва, проспект Вернадского, дом 86А
# 9202        город Москва, проспект Вернадского, дом 86А
# 9551  Российская Федерация, город Москва, внутригоро...

# %%
df_main = df_main[df_main['Address'].str.contains('86А')]
df_main[df_main['Address'].str.contains('86А')]
# Out:
#           ID                         Name  \
# 327   151596                      KVARTAL
# 2889  365140                   СИНЕМАСТАР
# 3781  262639                Star Hit cafe
# 4869  368180             One Price COFFEE
# 5913  361504                 Чистая линия
# 6295  198194                   Чайхона №1
# 6321  353516        О ХОТДОГ Даниель кафе
# 6374  134638                ПБО «Теремок»
# 6574  354593                  Bubbleology
# 7660  352541                   ХАВЧИК ТУТ
# 7674  134633                     ВОКМАНИЯ
# 9045  218279             Sushi store Суши
# 9202  298228                   BB&BURGERS
# 9551  285291  SHAN SHAN Вьетнамская кухня
#
#                                                 Address
# 327         город Москва, проспект Вернадского, дом 86А
# 2889        город Москва, проспект Вернадского, дом 86А
# 3781        город Москва, проспект Вернадского, дом 86А
# 4869        город Москва, проспект Вернадского, дом 86А
# 5913        город Москва, проспект Вернадского, дом 86А
# 6295        город Москва, проспект Вернадского, дом 86А
# 6321        город Москва, проспект Вернадского, дом 86А
# 6374        город Москва, проспект Вернадского, дом 86А
# 6574  Российская Федерация, город Москва, внутригоро...
# 7660        город Москва, проспект Вернадского, дом 86А
# 7674        город Москва, проспект Вернадского, дом 86А
# 9045        город Москва, проспект Вернадского, дом 86А
# 9202        город Москва, проспект Вернадского, дом 86А
# 9551  Российская Федерация, город Москва, внутригоро...

# %%
df_seats
# Out:
#            ID  SeatsCount  ver_ID
# 0      345181           0       1
# 1      326754          35       2
# 2      151037           0       1
# 3      277311          11       2
# 4      252377           2       1
# ...       ...         ...     ...
# 12995   58472          90       1
# 12996  372280          35       2
# 12997   26058         310       1
# 12998  190988          40       1
# 12999  356817           4       1
#
# [13000 rows x 3 columns]

# %%
# вот это самое непонятное: (взято из предыдущей задачи вообще как было):

# сортируем значения по ID и ver_ID ascending = False

# дропаем дубликаты, оставляем только первый - а это с ver_ID == 2.

# таким образом остаются либо чистые ver_ID == 2 либо ver_ID == 1 (у которых и не было обновлений до 2)

df_seats_ver_ID = df_seats.sort_values(by = ['ID', 'ver_ID'], ascending = False).drop_duplicates(subset = 'ID', keep = 'first')
df_seats.sort_values(by = ['ID', 'ver_ID'], ascending = False).drop_duplicates(subset = 'ID', keep = 'first')
# Out:
#            ID  SeatsCount  ver_ID
# 6693   375956           0       1
# 2158   375942           0       1
# 8637   375940          10       2
# 8218   375933           5       2
# 2212   375905          34       1
# ...       ...         ...     ...
# 1449    19681          24       1
# 5032    19678          46       1
# 10104   19657          85       2
# 3965    19627          20       2
# 673      5882          75       2
#
# [8432 rows x 3 columns]

# %%
pd.merge(df_main, df_seats_ver_ID, how = 'left')
# Out:
#         ID                         Name  \
# 0   151596                      KVARTAL
# 1   365140                   СИНЕМАСТАР
# 2   262639                Star Hit cafe
# 3   368180             One Price COFFEE
# 4   361504                 Чистая линия
# 5   198194                   Чайхона №1
# 6   353516        О ХОТДОГ Даниель кафе
# 7   134638                ПБО «Теремок»
# 8   354593                  Bubbleology
# 9   352541                   ХАВЧИК ТУТ
# 10  134633                     ВОКМАНИЯ
# 11  218279             Sushi store Суши
# 12  298228                   BB&BURGERS
# 13  285291  SHAN SHAN Вьетнамская кухня
#
#                                               Address  SeatsCount  ver_ID
# 0         город Москва, проспект Вернадского, дом 86А       105.0     2.0
# 1         город Москва, проспект Вернадского, дом 86А         NaN     NaN
# 2         город Москва, проспект Вернадского, дом 86А         NaN     NaN
# 3         город Москва, проспект Вернадского, дом 86А        15.0     2.0
# 4         город Москва, проспект Вернадского, дом 86А         NaN     NaN
# 5         город Москва, проспект Вернадского, дом 86А         NaN     NaN
# 6         город Москва, проспект Вернадского, дом 86А        10.0     1.0
# 7         город Москва, проспект Вернадского, дом 86А         NaN     NaN
# 8   Российская Федерация, город Москва, внутригоро...         5.0     2.0
# 9         город Москва, проспект Вернадского, дом 86А         NaN     NaN
# 10        город Москва, проспект Вернадского, дом 86А        65.0     2.0
# 11        город Москва, проспект Вернадского, дом 86А         9.0     2.0
# 12        город Москва, проспект Вернадского, дом 86А        29.0     2.0
# 13  Российская Федерация, город Москва, внутригоро...         NaN     NaN

# %%
pd.merge(df_main, df_seats_ver_ID, how = 'left')['SeatsCount'].sum()
# Out:
# 238.0
